# %% [markdown]
# ## **Function Calling LLMs - Team Project**

# %%
import openai
import json
import os

import pandas as pd
from pprint import pprint
from dotenv import load_dotenv


load_dotenv()
openai.api_key = os.environ.get("API_KEY")

# %% [markdown]
# ## Data

# %% [markdown]
# ##### Dataset 1: Most Popular Albums on Spotify
#
# Source: https://www.kaggle.com/datasets/tobennao/rym-top-5000/

# %%
album_columns_to_keep = ["release_name",    # Name of the album 
                            "artist_name",     # Name of the artist/band/group
                            "release_date",    # Date the album was released
                            "primary_genres",  # Primary genre classifications
                            "secondary_genres",# Secondary genre classifications
                            "descriptors",     # Album tags
                            "avg_rating",      # Average rating, on a scale of 0-5
                            "rating_count",    # The number of ratings
                            "review_count"     # The number of reviews
                        ]

albums_popular = pd.read_csv("./data/popular_albums.csv", usecols=album_columns_to_keep)


# one attribute for release_date
def combine_and_deduplicate_genres(primary, secondary):
    combined_genres = set()

    if primary and not isinstance(primary, float):
        combined_genres.update(primary.split(', '))

    if secondary and not isinstance(secondary, float):
        combined_genres.update(secondary.split(', '))

    return ', '.join(combined_genres)


albums_popular['genres'] = albums_popular.apply(lambda row: combine_and_deduplicate_genres(
    row['primary_genres'], row['secondary_genres']), axis=1)

albums_popular.drop(['primary_genres', 'secondary_genres'], axis=1, inplace=True)


# reorder:
new_order = ["release_name", "artist_name", "release_date", "genres",
             "descriptors", "avg_rating", "rating_count", "review_count"]
albums_popular = albums_popular[new_order]

# %%
album_columns_to_keep = ["release_name",    # Name of the album
                         "artist_name",     # Name of the artist/band/group
                         "release_date",    # Date the album was released
                         "genres",          # Genre
                         "descriptors",     # Album tags
                         "avg_rating",      # Average rating, on a scale of 0-5
                         "rating_count",    # The number of ratings
                         "review_count"     # The number of reviews
                         ]

albums_long_tail = pd.read_csv("./data/albums_long_tail.csv", usecols=album_columns_to_keep)

# %%
ALBUMS = pd.concat([albums_popular, albums_long_tail], ignore_index=True)

print(f"Attributes: {ALBUMS.columns.to_list()}")
print(f"Number of attributes (columns): {ALBUMS.shape[1]}")
print(f"Number of examples (rows): {ALBUMS.shape[0]}")

ALBUMS[-10:].head(n=10)
# Out:
# Attributes: ['release_name', 'artist_name', 'release_date', 'genres', 'descriptors', 'avg_rating', 'rating_count', 'review_count']
# Number of attributes (columns): 8
# Number of examples (rows): 5119
#                                            release_name  \
# 5109                              Dismantled Into Juice
# 5110                                    But Here We Are
# 5111  Metro Boomin Presents Spider-Man: Across the S...
# 5112                        Formal Growth in the Desert
# 5113                                              Bunny
# 5114                                 Everyone's Crushed
# 5115                                           Aperture
# 5116                     More Photographs (A Continuum)
# 5117                                            Perfume
# 5118                                          AESTHETIC
#
#                     artist_name release_date  \
# 5109                     Blawan   2023-05-17
# 5110               Foo Fighters   2023-06-02
# 5111               Metro Boomin   2023-06-02
# 5112                Protomartyr   2023-06-02
# 5113              Beach Fossils   2023-06-02
# 5114       Water From Your Eyes   2023-05-26
# 5115              Hannah Jadagu   2023-05-19
# 5116                Kevin Morby   2023-05-26
# 5117              NCT DOJAEJUNG   2023-04-17
# 5118  tripleS / +(KR)ystal Eyes   2023-05-04
#
#                                                  genres  \
# 5109   UK Bass, Wonky Techno, Deconstructed Club, Wonky
# 5110  Alternative Rock, Power Pop, Post-Grunge, Shoe...
# 5111  Film Soundtrack, Pop Rap, Trap, Afrobeats, Con...
# 5112       Post-Punk, Art Punk, Gothic Rock, Noise Rock
# 5113  Jangle Pop, Indie Pop, Dream Pop, Indie Surf, ...
# 5114  Experimental Rock, Art Pop, Neo-Psychedelia, P...
# 5115                  Indie Pop, Dream Pop, Bedroom Pop
# 5116  Folk Rock, Singer-Songwriter, Indie Folk, Amer...
# 5117  Contemporary R&B, K-Pop, Dance-Pop, Future Bas...
# 5118  K-Pop, Dance-Pop, Contemporary R&B, New Jack S...
#
#                                             descriptors  avg_rating  \
# 5109  mechanical, rhythmic, hypnotic, dissonant, raw...        3.34
# 5110  death, male vocalist, melodic, anthemic, bitte...        3.56
# 5111  male vocalist, female vocalist, optimistic, tr...        2.96
# 5112  male vocalist, dark, rhythmic, atmospheric, de...        3.45
# 5113  male vocalist, mellow, calm, soft, ethereal, w...        3.29
# 5114  apathetic, urban, dissonant, noisy, energetic,...        3.32
# 5115  bittersweet, melancholic, sentimental, energet...        3.44
# 5116  lonely, sentimental, melodic, male vocalist, w...        3.13
# 5117  sensual, male vocalist, melodic, rhythmic, rom...        3.44
# 5118  female vocalist, warm, rhythmic, lush, melodic...        3.50
#
#       rating_count  review_count
# 5109           527           2.0
# 5110          5118          76.0
# 5111          2295          19.0
# 5112          2785          29.0
# 5113           929           9.0
# 5114          1149          15.0
# 5115           293           4.0
# 5116           143           2.0
# 5117           360           3.0
# 5118           752           5.0

# %% [markdown]
# ##### Dataset 2: Most Streamed Tracks on Spotify
#
# Source: https://www.kaggle.com/datasets/nelgiriyewithana/top-spotify-songs-2023

# %%
song_columns_to_keep = ['track_name',           # Name of the song
                        'artist(s)_name',       # Name of the artist(s) of the song
                        'artist_count',         # Number of artists contributing to the song
                        'released_year',        # Year when the song was released
                        'released_month',       # Month when the song was released
                        'released_day',         # Day of the month when the song was released
                        'streams',              # Total number of streams on Spotify
                        'bpm',                  # Beats per minute, a measure of song tempo
                        'key',                  # Key of the song
                        'mode',                 # Mode of the song (major or minor)
                        'danceability_%',       # Percentage indicating how suitable the song is for dancing
                        'valence_%',            # Positivity of the song's musical content
                        'energy_%',             # Perceived energy level of the song
                        'acousticness_%',       # Amount of acoustic sound in the song
                        'instrumentalness_%',   # Amount of instrumental content in the song
                        'liveness_%',           # Presence of live performance elements
                        'speechiness_%'         # Amount of spoken words in the song
                        ]


songs_short_tail = pd.read_csv("./data/tracks.csv", encoding_errors="ignore")

# one attribute for release_date
songs_short_tail['release_date'] = pd.to_datetime(songs_short_tail['released_year'].astype(str) + '-' +
                                       songs_short_tail['released_month'].astype(str) + '-' +
                                       songs_short_tail['released_day'].astype(str))

songs_short_tail['release_date'] = songs_short_tail['release_date'].dt.date
songs_short_tail['release_date'] = songs_short_tail['release_date'].astype(str)

songs_short_tail.drop(['released_year', 'released_month',
        'released_day'], axis=1, inplace=True)


# reorder:
new_order = ['track_name', 'artist(s)_name', 'artist_count', 'release_date', 'streams', 'bpm', 'key', 'mode', 
             'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
songs_short_tail = songs_short_tail[new_order]

# %%
songs_long_tail = pd.read_csv("./data/tracks_long_tail.csv", encoding_errors="ignore")

# %%
SONGS = pd.concat([songs_short_tail, songs_long_tail], ignore_index=True)

print(f"Attributes: {SONGS.columns.to_list()}")
print(f"Number of attributes (columns): {SONGS.shape[1]}")
print(f"Number of examples (rows): {SONGS.shape[0]}")

SONGS[495:].head(n=25)
# Out:
# Attributes: ['track_name', 'artist(s)_name', 'artist_count', 'release_date', 'streams', 'bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%', 'album', 'explicit', 'popularity', 'duration_in_min']
# Number of attributes (columns): 19
# Number of examples (rows): 1413
#                                    track_name  \
# 495          Run Rudolph Run - Single Version
# 496            Jingle Bells - Remastered 1999
# 497                                       Far
# 498                On Time (with John Legend)
# 499                                     GAT��
# 500                                   abcdefu
# 501                                 Sacrifice
# 502                    Is There Someone Else?
# 503                           Fingers Crossed
# 504                               Out of Time
# 505                               Do It To It
# 506                 We Don't Talk About Bruno
# 507                                     Pepas
# 508                How Do I Make You Love Me?
# 509                                  Gasoline
# 510                                  Infinity
# 511                            Less Than Zero
# 512                            Take My Breath
# 513                                  good 4 u
# 514  Here We Go��� Again (feat. Tyler, the Cr
# 515                              Best Friends
# 516                  Kiss Me More (feat. SZA)
# 517  I Heard You're Married (feat. Lil Wayne)
# 518                              Need To Know
# 519            MONTERO (Call Me By Your Name)
#
#                                         artist(s)_name  artist_count  \
# 495                                        Chuck Berry             1
# 496                                      Frank Sinatra             1
# 497                                                SZA             1
# 498                          John Legend, Metro Boomin             2
# 499                                     Maldy, Karol G             2
# 500                                              Gayle             1
# 501                                         The Weeknd             1
# 502                                         The Weeknd             1
# 503  Lauren Spencer Smith, Lauren Spencer Smith, La...             3
# 504                                         The Weeknd             1
# 505                                    Cherish, ACRAZE             2
# 506  Adassa, Mauro Castillo, Stephanie Beatriz, Enc...             7
# 507                                            Farruko             1
# 508                                         The Weeknd             1
# 509                                         The Weeknd             1
# 510                                       Jaymes Young             1
# 511                                         The Weeknd             1
# 512                                         The Weeknd             1
# 513                                     Olivia Rodrigo             1
# 514                     The Weeknd, Tyler, The Creator             3
# 515                                         The Weeknd             1
# 516                                      SZA, Doja Cat             2
# 517                              The Weeknd, Lil Wayne             2
# 518                                           Doja Cat             1
# 519                                          Lil Nas X             1
#
#     release_date     streams  bpm  key   mode  danceability_%  valence_%  \
# 495   1958-01-01   245350949  152    G  Minor              69         94
# 496   1957-01-01   178660459  175   G#  Major              51         94
# 497   2022-12-09    51641685  116    D  Major              61         48
# 498   2022-12-02    78139948   80    F  Minor              33         51
# 499   2022-08-25   322336177   93    B  Minor              63         34
# 500   2021-08-13  1007612429  122    E  Major              70         42
# 501   2022-01-07   326792833  122    G  Major              70         91
# 502   2022-01-07   391251368  135    A  Minor              70         60
# 503   2022-01-05   349585590  109    F  Major              60         45
# 504   2022-01-07   339659802   93  NaN  Minor              65         82
# 505   2021-08-20   674772936  125    B  Minor              85         64
# 506   2021-11-19   432719968  206  NaN  Minor              58         83
# 507   2021-06-24  1309887447  130    G  Major              76         44
# 508   2022-01-07   119238316  121    G  Minor              80         62
# 509   2022-01-07   116903579  123   F#  Minor              74         35
# 510   2017-06-23   888046992  122    B  Minor              67         50
# 511   2022-01-07   200660871  143  NaN  Major              53         50
# 512   2021-08-06   130655803  121   A#  Minor              70         35
# 513   2021-05-14  1887039593  166   F#  Minor              56         68
# 514   2022-01-07    88103848  135   C#  Major              41         27
# 515   2022-01-07   101114984   87    E  Minor              49         49
# 516   2021-04-09  1575467011  111   G#  Major              77         74
# 517   2022-01-07    91656026  110    D  Major              75         85
# 518   2021-06-11  1042568408  130   C#  Major              66         19
# 519   2020-09-18  1735441776  179   G#  Minor              61         76
#
#      energy_%  acousticness_%  instrumentalness_%  liveness_%  speechiness_%  \
# 495        71              79                   0           7              8
# 496        34              73                   0          10              5
# 497        55              67                   0          16              8
# 498        59              76                   0          44              6
# 499        86              26                   0          21             39
# 500        54              30                   0          37              5
# 501        79               3                   0           7             10
# 502        58               4                   0          16              3
# 503        47              62                   0          31              5
# 504        74              27                   0          32              5
# 505        81               2                   5           7              9
# 506        45              36                   0          11              8
# 507        77               1                   0          13              3
# 508        51               2                   0           9              8
# 509        73               0                   0          21              5
# 510        67              15                   0          30              4
# 511        79               0                   0           8              3
# 512        77               1                   0          26              4
# 513        66              28                   0          11             18
# 514        64              36                   0          60              3
# 515        59              44                   0          35             21
# 516        66              30                   0          13              3
# 517        84              10                   0          31             19
# 518        61              30                   0           9              7
# 519        51              30                   0          38             15
#
#     album explicit  popularity  duration_in_min
# 495   NaN      NaN         NaN              NaN
# 496   NaN      NaN         NaN              NaN
# 497   NaN      NaN         NaN              NaN
# 498   NaN      NaN         NaN              NaN
# 499   NaN      NaN         NaN              NaN
# 500   NaN      NaN         NaN              NaN
# 501   NaN      NaN         NaN              NaN
# 502   NaN      NaN         NaN              NaN
# 503   NaN      NaN         NaN              NaN
# 504   NaN      NaN         NaN              NaN
# 505   NaN      NaN         NaN              NaN
# 506   NaN      NaN         NaN              NaN
# 507   NaN      NaN         NaN              NaN
# 508   NaN      NaN         NaN              NaN
# 509   NaN      NaN         NaN              NaN
# 510   NaN      NaN         NaN              NaN
# 511   NaN      NaN         NaN              NaN
# 512   NaN      NaN         NaN              NaN
# 513   NaN      NaN         NaN              NaN
# 514   NaN      NaN         NaN              NaN
# 515   NaN      NaN         NaN              NaN
# 516   NaN      NaN         NaN              NaN
# 517   NaN      NaN         NaN              NaN
# 518   NaN      NaN         NaN              NaN
# 519   NaN      NaN         NaN              NaN

# %% [markdown]
# ## Functions

# %% [markdown]
# #### Albums

# %%
def top_rated_albums(n=10):
    """
    Returns the top-rated albums based on average rating.
    
    Parameters:
        n (int): The number of albums to return. Default is 10.
    
    Returns:
        list[dict]: A list of dictionaries representing the top-rated albums.
    """
    top_rated = ALBUMS.sort_values(by='avg_rating', ascending=False).head(n)
    return top_rated.to_dict(orient='records')

def most_reviewed_albums(n=10):
    """
    Returns the most reviewed albums.
    
    Parameters:
        n (int): The number of albums to return. Default is 10.
    
    Returns:
        list[dict]: A list of dictionaries representing the most reviewed albums.
    """
    most_reviewed = ALBUMS.sort_values(by='review_count', ascending=False).head(n)
    return most_reviewed.to_dict(orient='records')
    
def albums_by_artist(artist_name):
    """
    Returns all albums by a given artist.
    
    Parameters:
        artist_name (str): The name of the artist.
    
    Returns:
        list[dict]: A list of dictionaries representing the albums by the given artist.
    """
    albums = ALBUMS[ALBUMS['artist_name'] == artist_name]
    return albums.to_dict(orient='records')

def artist_by_album(album_name):
    """
    Returns the artist of an album by its name.

    Parameters:
        album_name (str): The name of the album.

    Returns:
        dict: A dictionary with the album name and the artist.
              If the album is not found, the dictionary will be empty.
    """
    
    artist_dict = {}
    
    # Search for the album by name and populate the dictionary
    album = ALBUMS[ALBUMS['release_name'] == album_name]
    if not album.empty:
        artist_dict['Album name'] = album_name
        artist_dict['artist'] = album.iloc[0]['artist_name']
    
    return artist_dict

def albums_by_release_date(release_date):
    """
    Returns albums released on a specific date or within a specific year.

    Parameters:
        release_date (str): The release date in the format 'YYYY-MM-DD' or the release year in 'YYYY' format.

    Returns:
        list[dict]: A list of dictionaries representing the albums released on the specified date or within the specified year.
    """
    if len(release_date) == 4:
        # User provided only the year
        start_date = f'{release_date}-01-01'
        end_date = f'{release_date}-12-31'
    else:
        # User provided a full date
        start_date = release_date
        end_date = release_date

    albums_within_range = ALBUMS[(ALBUMS['release_date'] >= start_date) & (ALBUMS['release_date'] <= end_date)]
    
    return albums_within_range.to_dict(orient='records')

def albums_by_descriptors(descriptor):
    """
    Returns albums from the dataset that match the given descriptors.

    Parameters:
        descriptor (string): A string containing descriptors separated by comma.

    Returns:
        list[dict]: A list of dictionaries representing albums that match the given descriptors.
    """
    
    descriptor_list = descriptor.split(',') 
    albums = ALBUMS[ALBUMS['descriptors'].apply(lambda x: all(desc in x for desc in descriptor_list))]

    return albums.to_dict(orient='records')

# %% [markdown]
# #### Songs

# %%
def top_streamed_songs(n=10):
    """
    Returns the top-streamed songs.
    
    Parameters:
        n (int): The number of songs to return. Default is 10.
    
    Returns:
        list[dict]: A list of dictionaries representing the top-streamed songs.
    """
    top_songs = SONGS.sort_values(by='streams', ascending=False).head(n)
    return top_songs.to_dict(orient='records')

def songs_in_spotify_playlists(n=10):
    """
    Returns the top songs featured in the most Spotify playlists.
    
    Parameters:
        n (int): The number of songs to return. Default is 10.
    
    Returns:
        list[dict]: A list of dictionaries representing the songs featured in the most Spotify playlists.
    """
    top_playlist_songs = SONGS.sort_values(by='in_spotify_playlists', ascending=False).head(n)
    return top_playlist_songs.to_dict(orient='records')

def songs_by_artist(artist_name):
    """
    Returns all songs by a given artist.
    
    Parameters:
        artist_name (str): The name of the artist.
    
    Returns:
        list[dict]: A list of dictionaries representing the songs by the given artist.
    """
    songs = SONGS[SONGS['artist(s)_name'] == artist_name]
    return songs.to_dict(orient='records')

def artist_by_song(song_name):
    """
    Returns the artist of the song.

    Parameters:
        song_name (str): The name of the song.

    Returns:
        dict: A dictionary with the song name and the artist.
              If the song is not found, the dictionary will be empty.
    """
    
    artist_dict = {}
    
    # Search for the song by name and populate the dictionary
    song = SONGS[SONGS['track_name'] == song_name]
    if not song.empty:
        artist_dict['Song'] = song_name
        artist_dict['Artist'] = song.iloc[0]['artist(s)_name']
    
    return artist_dict

def songs_by_release_date(release_date):
    """
    Returns all songs released in the specified year or on a specific date.
    
    Parameters:
        release_date (str): The release date in the format 'YYYY-MM-DD' or the release year in 'YYYY' format.
    
    Returns:
        list[dict]: A list of dictionaries representing the songs released in the specified year.
    """
    
    if len(release_date) == 4:
        # User provided only the year
        start_date = f'{release_date}-01-01'
        end_date = f'{release_date}-12-31'
    else:
        # User provided a full date
        start_date = release_date
        end_date = release_date

    songs = SONGS[(SONGS['release_date'] >= start_date) & (SONGS['release_date'] <= end_date)]
    
    return songs.to_dict(orient='records')

# %% [markdown]
# ##### Metadata

# %%
def filter_functions(functions_list, function_metadata):
    function_names = [func.__name__ for func in functions_list]
    filtered_metadata = [meta for meta in function_metadata if meta.get('name') in function_names]
    return functions_list, filtered_metadata

def describe_function(available_functions):
    return [meta["description"] for meta in available_functions[1]]

# %% [markdown]
# ## LLM

# %%
from enum import Enum
from openai.openai_object import OpenAIObject

class Role(Enum):
    ASSISTANT = "assistant"
    FUNCTION = "function"
    SYSTEM = "system"
    USER = "user"
    
class Model(Enum):
    GPT3 = "gpt-3.5-turbo-0613"
    GPT4 = "gpt-4-0613"

class FunctionNotFoundError(Exception):
    def __init__(self, function_name, function_args):
        self.function_name = function_name
        self.function_args = function_args
        super().__init__(f"Error finding function {function_name} with arguments {function_args}")

class FunctionExecutionError(Exception):
    def __init__(self, function_name, function_args):
        self.function_name = function_name
        self.function_args = function_args
        super().__init__(f"Error executing function {function_name} with arguments {function_args}")


class Response:
    def __init__(self, message:dict):
        self._message = message
        
    @classmethod
    def from_api(cls, openai_response:OpenAIObject):
        _message = openai_response["choices"][0]["message"]
        return cls(_message)
    
    @property
    def message(self) -> str:
        return self._message["content"]

    @property
    def role(self) -> str:
        return self._message["role"]

    @property
    def function(self) -> dict:
        return self._message.get("function_call")

    @property
    def is_function_call(self) -> bool:
        return self.function is not None
    
    def to_dict(self) -> dict:
        return {**self._message}
    
    def __str__(self):
        return f"Response({self.role}: {self.message}, with function:{self.function})"


class Conversation:
    def __init__(self):
        self._messages = []

    @property
    def messages_as_dicts(self):
        return [message.to_dict() for message in self._messages]

    def send(self, model, functions) -> Response:

        args = {"model":model, 
                "messages":self.messages_as_dicts}
        
        if len(functions) > 0:
            args.update({"function_call":"auto",
                         "functions":functions})
            
        response = openai.ChatCompletion.create(**args)
        return Response.from_api(response)

    def add(self, message_or_response):
        if isinstance(message_or_response, Response):
            message = message_or_response
        else:
            message = Response(message_or_response)

        self._messages.append(message)        
        return self
    
    def __str__(self):
        return f"{self.messages_as_dicts}"
    

def handle_function(function:dict, functions) -> json:
    """Invoke function and return result"""
    function_name, function_args = function["name"], json.loads(function["arguments"])
    
    def get_function_by_name():
        for func in functions:
            if func.__name__ == function_name:
                return func
        return None
    
    function_to_call = get_function_by_name()
    if function_to_call is not None:
        try:
            result = json.dumps(function_to_call(**function_args))
            return result
        except:
            raise FunctionExecutionError(function_name, function_args)
    else:
        raise FunctionNotFoundError(function_name, function_args)


# TODO
def handle_error(error, retry):
    raise error


max_iterations = 5
def chat(conversation:Conversation, model:str, functions:tuple) -> str:
    iteration = 0
    while iteration < max_iterations:
        iteration +=1
        response = conversation.send(model, functions[1])
        conversation.add(response)
        
        if response.is_function_call:
            try:
                result = handle_function(response.function, functions[0])
                conversation.add({"role": Role.FUNCTION.value, "content": result, "name":response.function["name"]})
            except (FunctionNotFoundError, FunctionExecutionError) as error:
                handle_error(error=error, retry=False)
        else:
            return response.message
        

def handle_function_on_server(function):
    function_name, function_args = function["name"], json.loads(
        function["arguments"])
    
    import requests
    
    URL = f"http://localhost:5000/function_call/{function_name}?"
    
    response = requests.get(URL, params=function_args)
    if response.ok:
        data = response.json()
        return data["result"]
    else:
        raise FunctionExecutionError # TODO
    
    

PORT = 5000
def chat_web(conversation: Conversation, model: str, function_metadata: list) -> str:
    iteration = 0
    while iteration < max_iterations:
        iteration += 1
        response = conversation.send(model, function_metadata)
        conversation.add(response)

        if response.is_function_call:
            try:
                result = handle_function_on_server(response.function)
                conversation.add(
                    {"role": Role.FUNCTION.value, "content": result, "name": response.function["name"]})
            except (FunctionNotFoundError, FunctionExecutionError) as error:
                handle_error(error=error, retry=False)
        else:
            return response.message

# %% [markdown]
# ## Benchmark

# %%
all_functions = [top_rated_albums, most_reviewed_albums, albums_by_artist, top_streamed_songs, songs_in_spotify_playlists, songs_by_artist, artist_by_song, artist_by_album, albums_by_release_date, albums_by_descriptors, songs_by_release_date]

with open('functions.json', 'r') as file:
    function_metadata = json.load(file)

# %%
print("Functions: " + str(len(all_functions)))
print(all_functions)

print()
print("Metadata: " + str(len(function_metadata)))
for meta_data in function_metadata:
    print(f"{meta_data['name']}: {meta_data['description']}")
# Out:
# Functions: 11
# [<function top_rated_albums at 0x000002322E5BE700>, <function most_reviewed_albums at 0x0000023231B81790>, <function albums_by_artist at 0x0000023231B81310>, <function top_streamed_songs at 0x0000023231B81AF0>, <function songs_in_spotify_playlists at 0x0000023231B7C9D0>, <function songs_by_artist at 0x0000023231B7C940>, <function artist_by_song at 0x0000023231B7CCA0>, <function artist_by_album at 0x0000023231B818B0>, <function albums_by_release_date at 0x0000023231B7C790>, <function albums_by_descriptors at 0x0000023231B7C820>, <function songs_by_release_date at 0x0000023231B7CD30>]
#
# Metadata: 11
# top_rated_albums: Retrieve the top-rated albums based on average rating.
# most_reviewed_albums: Retrieve the most reviewed albums.
# albums_by_artist: Retrieve all albums by a given artist.
# top_streamed_songs: Retrieve the top-streamed songs.
# songs_in_spotify_playlists: Retrieve the top songs featured in the most Spotify playlists.
# songs_by_artist: Retrieve all songs by a given artist.
# artist_by_song: Retrieve the artist of the specified song.
# artist_by_album: Retrieve the artist of the specified album.
# albums_by_release_date: Returns albums released on a specific date or within a specific year.
# songs_by_release_date: Returns all songs released in the specified year or on a specific date.
# albums_by_descriptors: Returns albums from the dataset that match the given descriptors.

# %% [markdown]
# #### Functions

# %% [markdown]
# ## AGGREGATION QUESTIONS

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
            .add({"role": Role.USER.value, "content": "What is the average rating of all the albums of Red Hot Chilli Peppers?"})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# The average rating of all the albums of Red Hot Chili Peppers is 3.07.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'What is the average rating of all the albums of Red Hot Chilli '
#              'Peppers?',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n'
#                                  '  "artist_name": "Red Hot Chili Peppers"\n'
#                                  '}',
#                     'name': 'albums_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "Californication", "artist_name": "Red Hot '
#              'Chili Peppers", "release_date": "1999-06-08", "genres": '
#              '"Alternative Rock, Funk Rock", "descriptors": "summer, '
#              'energetic, melodic, malevocals, playful, introspective, '
#              'bittersweet, eclectic, rhythmic, drugs", "avg_rating": 3.48, '
#              '"rating_count": 16401, "review_count": 286.0}, {"release_name": '
#              '"Blood Sugar Sex Magik", "artist_name": "Red Hot Chili Peppers", '
#              '"release_date": "1991-09-24", "genres": "Alternative Rock, Rap '
#              'Rock, Funk Rock", "descriptors": "sexual, energetic, playful, '
#              'drugs, humorous, vulgar, summer, malevocals, bittersweet, '
#              'rhythmic", "avg_rating": 3.6, "rating_count": 15587, '
#              '"review_count": 343.0}, {"release_name": "By the Way", '
#              '"artist_name": "Red Hot Chili Peppers", "release_date": '
#              '"2002-07-08", "genres": "Alternative Rock, Psychedelic Rock, '
#              'Funk Rock, Pop Rock", "descriptors": "summer, energetic, mellow, '
#              'melodic, malevocals, melancholic, warm, death, love, lush", '
#              '"avg_rating": 3.29, "rating_count": 10552, "review_count": '
#              '250.0}, {"release_name": "Stadium Arcadium", "artist_name": "Red '
#              'Hot Chili Peppers", "release_date": "2006-05-09", "genres": '
#              '"Alternative Rock, Funk Rock, Pop Rock", "descriptors": '
#              '"malevocals, energetic, playful, melodic, anthemic, eclectic, '
#              'melancholic, sexual, urban, summer", "avg_rating": 3.01, '
#              '"rating_count": 9590, "review_count": 312.0}, {"release_name": '
#              '"Mother\'s Milk", "artist_name": "Red Hot Chili Peppers", '
#              '"release_date": "1989-08-04", "genres": "Alternative Rock, Rap '
#              'Rock, Funk Metal, Funk Rock", "descriptors": "energetic, '
#              'malevocals, eclectic, sexual, hedonistic, playful, rhythmic, '
#              'humorous, vulgar, boastful", "avg_rating": 3.29, "rating_count": '
#              '5637, "review_count": 115.0}, {"release_name": "I\'m With You", '
#              '"artist_name": "Red Hot Chili Peppers", "release_date": '
#              '"2011-08-29", "genres": "Alternative Rock, Funk Rock, Pop Rock", '
#              '"descriptors": "melodic, energetic, optimistic, malevocals, '
#              'love", "avg_rating": 2.62, "rating_count": 4139, "review_count": '
#              '85.0}, {"release_name": "The Getaway", "artist_name": "Red Hot '
#              'Chili Peppers", "release_date": "2016-06-17", "genres": '
#              '"Alternative Rock, Funk Rock, Pop Rock", "descriptors": '
#              '"melodic, summer, malevocals, melancholic, playful, bittersweet, '
#              'uplifting, introspective, anthemic, warm", "avg_rating": 2.81, '
#              '"rating_count": 3586, "review_count": 39.0}]',
#   'name': 'albums_by_artist',
#   'role': 'function'},
#  {'content': 'The average rating of all the albums of Red Hot Chili Peppers is '
#              '3.07.',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
            .add({"role": Role.USER.value, "content": "How many persons have reviewed the albums of Radiohead?"})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# The albums of Radiohead have been reviewed by a total of 7,406 persons.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'How many persons have reviewed the albums of Radiohead?',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "artist_name": "Radiohead"\n}',
#                     'name': 'albums_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "OK Computer", "artist_name": "Radiohead", '
#              '"release_date": "1997-06-16", "genres": "Alternative Rock, Art '
#              'Rock", "descriptors": "melancholic, anxious, futuristic, '
#              'malevocals, existential, alienation, atmospheric, lonely, cold, '
#              'pessimistic", "avg_rating": 4.24, "rating_count": 74027, '
#              '"review_count": 1541.0}, {"release_name": "Kid A", '
#              '"artist_name": "Radiohead", "release_date": "2000-10-03", '
#              '"genres": "Ambient, IDM, Electronic, Experimental Rock, Art '
#              'Rock", "descriptors": "cold, melancholic, futuristic, anxious, '
#              'atmospheric, sombre, cryptic, abstract, introspective, '
#              'malevocals", "avg_rating": 4.23, "rating_count": 61658, '
#              '"review_count": 751.0}, {"release_name": "In Rainbows", '
#              '"artist_name": "Radiohead", "release_date": "2007-10-10", '
#              '"genres": "Dream Pop, Art Pop, Alternative Rock, Electronic, Art '
#              'Rock", "descriptors": "lush, malevocals, introspective, '
#              'melancholic, bittersweet, mellow, atmospheric, warm, ethereal, '
#              'longing", "avg_rating": 4.2, "rating_count": 51335, '
#              '"review_count": 752.0}, {"release_name": "The Bends", '
#              '"artist_name": "Radiohead", "release_date": "1995-03-13", '
#              '"genres": "Alternative Rock, Britpop", "descriptors": '
#              '"melancholic, lonely, melodic, anxious, introspective, '
#              'malevocals, bittersweet, existential, alienation, longing", '
#              '"avg_rating": 3.84, "rating_count": 48578, "review_count": '
#              '798.0}, {"release_name": "Amnesiac", "artist_name": "Radiohead", '
#              '"release_date": "2001-06-04", "genres": "Art Pop, Electronic, '
#              'Experimental Rock, Jazz-Rock, Art Rock", "descriptors": '
#              '"anxious, sombre, melancholic, atmospheric, cryptic, abstract, '
#              'mysterious, cold, malevocals, dark", "avg_rating": 3.79, '
#              '"rating_count": 39826, "review_count": 549.0}, {"release_name": '
#              '"Hail to the Thief", "artist_name": "Radiohead", "release_date": '
#              '"2003-06-09", "genres": "Alternative Rock, Electronic, Art '
#              'Rock", "descriptors": "political, eclectic, anxious, sombre, '
#              'malevocals, cryptic, melancholic, conscious, alienation, '
#              'complex", "avg_rating": 3.66, "rating_count": 35491, '
#              '"review_count": 493.0}, {"release_name": "A Moon Shaped Pool", '
#              '"artist_name": "Radiohead", "release_date": "2016-05-08", '
#              '"genres": "Art Pop, Ambient Pop, Electronic, Chamber Pop, Art '
#              'Rock", "descriptors": "atmospheric, melancholic, introspective, '
#              'sombre, lush, mellow, malevocals, mysterious, soft, sad", '
#              '"avg_rating": 3.9, "rating_count": 31081, "review_count": '
#              '276.0}, {"release_name": "Pablo Honey", "artist_name": '
#              '"Radiohead", "release_date": "1993-04-20", "genres": '
#              '"Alternative Rock, Grunge, Britpop", "descriptors": "lonely, '
#              'melancholic, anxious, energetic, malevocals, introspective, '
#              'self-hatred, sarcastic, noisy, alienation", "avg_rating": 2.71, '
#              '"rating_count": 28599, "review_count": 496.0}, {"release_name": '
#              '"The King of Limbs", "artist_name": "Radiohead", "release_date": '
#              '"2011-02-18", "genres": "Glitch Pop, Electronic, IDM, '
#              'Experimental Rock", "descriptors": "hypnotic, atmospheric, '
#              'nature, abstract, mysterious, forest, mellow, melancholic, '
#              'rhythmic, malevocals", "avg_rating": 3.25, "rating_count": '
#              '25256, "review_count": 485.0}, {"release_name": "In Rainbows '
#              'Disk 2", "artist_name": "Radiohead", "release_date": '
#              '"2009-06-09", "genres": "Alternative Rock, Electronic, Ambient, '
#              'Art Rock", "descriptors": "malevocals, atmospheric, lush, '
#              'melancholic, mellow, warm, bittersweet, anxious, rhythmic, '
#              'eclectic", "avg_rating": 3.54, "rating_count": 5313, '
#              '"review_count": 20.0}]',
#   'name': 'albums_by_artist',
#   'role': 'function'},
#  {'content': 'The albums of Radiohead have been reviewed by a total of 7,406 '
#              'persons.',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
            .add({"role": Role.USER.value, "content": "Among the top 20 rated albums, which one has the lowest number of reviews?"})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# Among the top 20 rated albums, the one with the lowest number of reviews is "The Rise and Fall of Ziggy Stardust and the Spiders From Mars" by David Bowie, with 729 reviews.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'Among the top 20 rated albums, which one has the lowest number '
#              'of reviews?',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "n": 20\n}',
#                     'name': 'top_rated_albums'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "The Black Saint and the Sinner Lady", '
#              '"artist_name": "Mingus", "release_date": "1963-07-01", "genres": '
#              '"Flamenco Jazz, Avant-Garde Jazz, Experimental Big Band, Third '
#              'Stream", "descriptors": "instrumental, complex, passionate, '
#              'suite, dense, avant-garde, suspenseful, technical, conceptalbum, '
#              'manic", "avg_rating": 4.34, "rating_count": 21489, '
#              '"review_count": 369.0}, {"release_name": "A Love Supreme", '
#              '"artist_name": "John Coltrane", "release_date": "1965-02-01", '
#              '"genres": "Modal Jazz, Post-Bop, Spiritual Jazz", "descriptors": '
#              '"improvisation, passionate, spiritual, instrumental, complex, '
#              'suite, acoustic, meditative, avant-garde, religious", '
#              '"avg_rating": 4.3, "rating_count": 26404, "review_count": '
#              '441.0}, {"release_name": "Wish You Were Here", "artist_name": '
#              '"Pink Floyd", "release_date": "1975-09-12", "genres": '
#              '"Psychedelic Rock, Space Rock, Progressive Rock, Art Rock", '
#              '"descriptors": "melancholic, atmospheric, progressive, '
#              'malevocals, conceptalbum, serious, introspective, longing, '
#              'alienation, bittersweet", "avg_rating": 4.3, "rating_count": '
#              '51246, "review_count": 1006.0}, {"release_name": "To Pimp a '
#              'Butterfly", "artist_name": "Kendrick Lamar", "release_date": '
#              '"2015-03-15", "genres": "West Coast Hip Hop, Poetry, Conscious '
#              'Hip Hop, Experimental Hip Hop, Funk, Jazz Rap, Political Hip '
#              'Hop, Neo-Soul", "descriptors": "political, conscious, poetic, '
#              'conceptalbum, protest, introspective, urban, malevocals, '
#              'eclectic, passionate", "avg_rating": 4.3, "rating_count": 47821, '
#              '"review_count": 415.0}, {"release_name": "In the Court of the '
#              'Crimson King", "artist_name": "King Crimson", "release_date": '
#              '"1969-10-10", "genres": "Free Improvisation, Progressive Rock, '
#              'Symphonic Prog, Jazz-Rock, Psychedelic Rock, Art Rock", '
#              '"descriptors": "fantasy, epic, progressive, complex, '
#              'philosophical, surreal, poetic, malevocals, melancholic, '
#              'abstract", "avg_rating": 4.3, "rating_count": 47415, '
#              '"review_count": 833.0}, {"release_name": "Madvillainy", '
#              '"artist_name": "Madvillain", "release_date": "2004-03-23", '
#              '"genres": "Abstract Hip Hop, Experimental Hip Hop, Instrumental '
#              'Hip Hop, Jazz Rap", "descriptors": "sampling, playful, humorous, '
#              'cryptic, abstract, mysterious, eclectic, malevocals, surreal, '
#              'boastful", "avg_rating": 4.28, "rating_count": 38684, '
#              '"review_count": 397.0}, {"release_name": "The Rise and Fall of '
#              'Ziggy Stardust and the Spiders From Mars", "artist_name": "David '
#              'Bowie", "release_date": "1972-06-16", "genres": "Rock Opera, '
#              'Glam Rock, Art Rock, Pop Rock", "descriptors": "sciencefiction, '
#              'melodic, malevocals, anthemic, conceptalbum, passionate, '
#              'rockopera, bittersweet, energetic, triumphant", "avg_rating": '
#              '4.26, "rating_count": 41613, "review_count": 729.0}, '
#              '{"release_name": "Remain in Light", "artist_name": "Talking '
#              'Heads", "release_date": "1980-10-08", "genres": "New Wave, '
#              'Afrobeat, Dance-Punk, Funk, Experimental Rock, Post-Punk", '
#              '"descriptors": "rhythmic, anxious, energetic, malevocals, '
#              'playful, cryptic, abstract, repetitive, quirky, philosophical", '
#              '"avg_rating": 4.25, "rating_count": 38220, "review_count": '
#              '532.0}, {"release_name": "Abbey Road", "artist_name": "The '
#              'Beatles", "release_date": "1969-09-26", "genres": "Progressive '
#              'Pop, Psychedelic Pop, Pop Rock", "descriptors": "melodic, warm, '
#              'malevocals, summer, bittersweet, uplifting, love, romantic, '
#              'eclectic, sentimental", "avg_rating": 4.25, "rating_count": '
#              '46968, "review_count": 969.0}, {"release_name": "OK Computer", '
#              '"artist_name": "Radiohead", "release_date": "1997-06-16", '
#              '"genres": "Alternative Rock, Art Rock", "descriptors": '
#              '"melancholic, anxious, futuristic, malevocals, existential, '
#              'alienation, atmospheric, lonely, cold, pessimistic", '
#              '"avg_rating": 4.24, "rating_count": 74027, "review_count": '
#              '1541.0}, {"release_name": "Loveless", "artist_name": "My Bloody '
#              'Valentine", "release_date": "1991-11-11", "genres": "Shoegaze, '
#              'Noise Pop, Dream Pop, Neo-Psychedelia", "descriptors": "noisy, '
#              'ethereal, atmospheric, romantic, love, dense, hypnotic, '
#              'psychedelic, femalevocals, lush", "avg_rating": 4.24, '
#              '"rating_count": 53174, "review_count": 1264.0}, {"release_name": '
#              '"Kid A", "artist_name": "Radiohead", "release_date": '
#              '"2000-10-03", "genres": "Ambient, IDM, Electronic, Experimental '
#              'Rock, Art Rock", "descriptors": "cold, melancholic, futuristic, '
#              'anxious, atmospheric, sombre, cryptic, abstract, introspective, '
#              'malevocals", "avg_rating": 4.23, "rating_count": 61658, '
#              '"review_count": 751.0}, {"release_name": "Revolver", '
#              '"artist_name": "The Beatles", "release_date": "1966-08-05", '
#              '"genres": "Psychedelic Rock, Psychedelic Pop, Pop Rock", '
#              '"descriptors": "psychedelic, melodic, malevocals, eclectic, '
#              'drugs, playful, warm, quirky, happy, surreal", "avg_rating": '
#              '4.23, "rating_count": 45401, "review_count": 1169.0}, '
#              '{"release_name": "Kind of Blue", "artist_name": "Miles Davis", '
#              '"release_date": "1959-08-17", "genres": "Modal Jazz, Cool Jazz", '
#              '"descriptors": "instrumental, mellow, improvisation, nocturnal, '
#              'soothing, calm, acoustic, meditative", "avg_rating": 4.23, '
#              '"rating_count": 31262, "review_count": 556.0}, {"release_name": '
#              '"The Velvet Underground & Nico", "artist_name": "The Velvet '
#              'Underground & Nico", "release_date": "1967-03-12", "genres": '
#              '"Noise Rock, Experimental Rock, Proto-Punk, Psychedelic Rock, '
#              'Garage Rock, Art Rock", "descriptors": "drugs, sexual, raw, '
#              'urban, noisy, malevocals, eclectic, femalevocals, avant-garde, '
#              'nihilistic", "avg_rating": 4.23, "rating_count": 47601, '
#              '"review_count": 944.0}, {"release_name": "Red", "artist_name": '
#              '"King Crimson", "release_date": "1974-10-06", "genres": "Free '
#              'Improvisation, Progressive Rock, Jazz-Rock, Hard Rock, Art '
#              'Rock", "descriptors": "dark, anxious, heavy, technical, ominous, '
#              'complex, uncommontimesignatures, progressive, malevocals, '
#              'nocturnal", "avg_rating": 4.22, "rating_count": 24763, '
#              '"review_count": 416.0}, {"release_name": "good kid, m.A.A.d '
#              'city", "artist_name": "Kendrick Lamar", "release_date": '
#              '"2012-10-22", "genres": "West Coast Hip Hop, Trap, Conscious Hip '
#              'Hop, Pop Rap, Hardcore Hip Hop", "descriptors": "urban, crime, '
#              'conceptalbum, conscious, introspective, malevocals, passionate, '
#              'Christian, violence, bittersweet", "avg_rating": 4.22, '
#              '"rating_count": 41799, "review_count": 317.0}, {"release_name": '
#              '"The Dark Side of the Moon", "artist_name": "Pink Floyd", '
#              '"release_date": "1973-03-23", "genres": "Psychedelic Rock, Space '
#              'Rock, Progressive Rock, Art Rock", "descriptors": '
#              '"philosophical, atmospheric, introspective, existential, mellow, '
#              'conceptalbum, malevocals, psychedelic, progressive, epic", '
#              '"avg_rating": 4.21, "rating_count": 60192, "review_count": '
#              '1557.0}, {"release_name": "Illmatic", "artist_name": "Nas", '
#              '"release_date": "1994-04-19", "genres": "East Coast Hip Hop, '
#              'Conscious Hip Hop, Boom Bap, Jazz Rap, Hardcore Hip Hop", '
#              '"descriptors": "urban, crime, introspective, sampling, drugs, '
#              'rhythmic, conscious, philosophical, malevocals, boastful", '
#              '"avg_rating": 4.21, "rating_count": 32875, "review_count": '
#              '624.0}, {"release_name": "In a Silent Way", "artist_name": '
#              '"Miles Davis", "release_date": "1969-07-30", "genres": "Jazz '
#              'Fusion, Modal Jazz, Avant-Garde Jazz", "descriptors": '
#              '"instrumental, mellow, atmospheric, nocturnal, improvisation, '
#              'mysterious, calm, soothing, meditative, hypnotic", "avg_rating": '
#              '4.21, "rating_count": 18132, "review_count": 297.0}]',
#   'name': 'top_rated_albums',
#   'role': 'function'},
#  {'content': 'Among the top 20 rated albums, the one with the lowest number of '
#              'reviews is "The Rise and Fall of Ziggy Stardust and the Spiders '
#              'From Mars" by David Bowie, with 729 reviews.',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
            .add({"role": Role.USER.value, "content": "How many songs were released in 2000?"})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# There were 4 songs released in 2000.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'How many songs were released in 2000?', 'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "release_date": "2000"\n}',
#                     'name': 'songs_by_release_date'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "The Real Slim Shady", "artist(s)_name": '
#              '"Eminem", "artist_count": 1, "release_date": "2000-01-01", '
#              '"streams": "1424589568", "bpm": 104, "key": "F", "mode": '
#              '"Minor", "danceability_%": 95, "valence_%": 78, "energy_%": 66, '
#              '"acousticness_%": 3, "instrumentalness_%": 0, "liveness_%": 4, '
#              '"speechiness_%": 6, "album": NaN, "explicit": NaN, "popularity": '
#              'NaN, "duration_in_min": NaN}, {"track_name": "In The End", '
#              '"artist(s)_name": "Linkin Park", "artist_count": 1, '
#              '"release_date": "2000-10-24", "streams": "1624165576", "bpm": '
#              '105, "key": "D#", "mode": "Minor", "danceability_%": 55, '
#              '"valence_%": 40, "energy_%": 90, "acousticness_%": 1, '
#              '"instrumentalness_%": 0, "liveness_%": 32, "speechiness_%": 6, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "My Only Wish (This '
#              'Year)", "artist(s)_name": "Britney Spears", "artist_count": 1, '
#              '"release_date": "2000-11-07", "streams": "261116938", "bpm": '
#              '147, "key": NaN, "mode": "Major", "danceability_%": 67, '
#              '"valence_%": 69, "energy_%": 72, "acousticness_%": 17, '
#              '"instrumentalness_%": 0, "liveness_%": 19, "speechiness_%": 3, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Sparks", '
#              '"artist(s)_name": "Coldplay", "artist_count": 1, "release_date": '
#              '"2000-07-10", "streams": "624101957", "bpm": 103, "key": "C#", '
#              '"mode": "Major", "danceability_%": 37, "valence_%": 17, '
#              '"energy_%": 27, "acousticness_%": 75, "instrumentalness_%": 5, '
#              '"liveness_%": 10, "speechiness_%": 3, "album": NaN, "explicit": '
#              'NaN, "popularity": NaN, "duration_in_min": NaN}]',
#   'name': 'songs_by_release_date',
#   'role': 'function'},
#  {'content': 'There were 4 songs released in 2000.', 'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
            .add({"role": Role.USER.value, "content": "Of all the songs of Ed Sheeran, which one is the most streamed?"})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# The most streamed song of Ed Sheeran is "Shape of You" with a total of 3,562,543,890 streams.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'Of all the songs of Ed Sheeran, which one is the most streamed?',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "artist_name": "Ed Sheeran"\n}',
#                     'name': 'songs_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "Perfect", "artist(s)_name": "Ed Sheeran", '
#              '"artist_count": 1, "release_date": "2017-01-01", "streams": '
#              '"2559529074", "bpm": 95, "key": "G#", "mode": "Major", '
#              '"danceability_%": 60, "valence_%": 17, "energy_%": 45, '
#              '"acousticness_%": 16, "instrumentalness_%": 0, "liveness_%": 11, '
#              '"speechiness_%": 2, "album": NaN, "explicit": NaN, "popularity": '
#              'NaN, "duration_in_min": NaN}, {"track_name": "Shape of You", '
#              '"artist(s)_name": "Ed Sheeran", "artist_count": 1, '
#              '"release_date": "2017-01-06", "streams": "3562543890", "bpm": '
#              '96, "key": "C#", "mode": "Minor", "danceability_%": 83, '
#              '"valence_%": 93, "energy_%": 65, "acousticness_%": 58, '
#              '"instrumentalness_%": 0, "liveness_%": 9, "speechiness_%": 8, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Eyes Closed", '
#              '"artist(s)_name": "Ed Sheeran", "artist_count": 1, '
#              '"release_date": "2023-03-23", "streams": "195576623", "bpm": '
#              '107, "key": "D", "mode": "Major", "danceability_%": 78, '
#              '"valence_%": 39, "energy_%": 53, "acousticness_%": 30, '
#              '"instrumentalness_%": 0, "liveness_%": 11, "speechiness_%": 6, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Curtains", '
#              '"artist(s)_name": "Ed Sheeran", "artist_count": 1, '
#              '"release_date": "2023-05-05", "streams": "39893489", "bpm": 176, '
#              '"key": "F#", "mode": "Minor", "danceability_%": 50, "valence_%": '
#              '44, "energy_%": 76, "acousticness_%": 10, "instrumentalness_%": '
#              '0, "liveness_%": 32, "speechiness_%": 5, "album": NaN, '
#              '"explicit": NaN, "popularity": NaN, "duration_in_min": NaN}, '
#              '{"track_name": "Shivers", "artist(s)_name": "Ed Sheeran", '
#              '"artist_count": 1, "release_date": "2021-09-09", "streams": '
#              '"1302184087", "bpm": 141, "key": "D", "mode": "Major", '
#              '"danceability_%": 79, "valence_%": 82, "energy_%": 86, '
#              '"acousticness_%": 28, "instrumentalness_%": 0, "liveness_%": 4, '
#              '"speechiness_%": 9, "album": NaN, "explicit": NaN, "popularity": '
#              'NaN, "duration_in_min": NaN}, {"track_name": "Bad Habits", '
#              '"artist(s)_name": "Ed Sheeran", "artist_count": 1, '
#              '"release_date": "2020-09-03", "streams": "1555511105", "bpm": '
#              '126, "key": "B", "mode": "Minor", "danceability_%": 81, '
#              '"valence_%": 59, "energy_%": 90, "acousticness_%": 5, '
#              '"instrumentalness_%": 0, "liveness_%": 36, "speechiness_%": 3, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Thinking Out Loud", '
#              '"artist(s)_name": "Ed Sheeran", "artist_count": 1, '
#              '"release_date": "2014-01-01", "streams": "2280566092", "bpm": '
#              '79, "key": "D", "mode": "Major", "danceability_%": 78, '
#              '"valence_%": 58, "energy_%": 45, "acousticness_%": 47, '
#              '"instrumentalness_%": 0, "liveness_%": 18, "speechiness_%": 3, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Photograph", '
#              '"artist(s)_name": "Ed Sheeran", "artist_count": 1, '
#              '"release_date": "2014-06-20", "streams": "2236667932", "bpm": '
#              '108, "key": "E", "mode": "Major", "danceability_%": 61, '
#              '"valence_%": 20, "energy_%": 38, "acousticness_%": 61, '
#              '"instrumentalness_%": 0, "liveness_%": 10, "speechiness_%": 5, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Celestial", '
#              '"artist(s)_name": "Ed Sheeran", "artist_count": 1, '
#              '"release_date": "2022-09-29", "streams": "176474912", "bpm": '
#              '123, "key": "D", "mode": "Major", "danceability_%": 57, '
#              '"valence_%": 50, "energy_%": 85, "acousticness_%": 5, '
#              '"instrumentalness_%": 0, "liveness_%": 16, "speechiness_%": 4, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}]',
#   'name': 'songs_by_artist',
#   'role': 'function'},
#  {'content': 'The most streamed song of Ed Sheeran is "Shape of You" with a '
#              'total of 3,562,543,890 streams.',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
            .add({"role": Role.USER.value, "content": "Can you provide me the average value of beats per minute for the songs of Olivia Rodrigo."})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# The average value of beats per minute for Olivia Rodrigo's songs is approximately 160.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'Can you provide me the average value of beats per minute for the '
#              'songs of Olivia Rodrigo.',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "artist_name": "Olivia Rodrigo"\n}',
#                     'name': 'songs_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "vampire", "artist(s)_name": "Olivia Rodrigo", '
#              '"artist_count": 1, "release_date": "2023-06-30", "streams": '
#              '"140003974", "bpm": 138, "key": "F", "mode": "Major", '
#              '"danceability_%": 51, "valence_%": 32, "energy_%": 53, '
#              '"acousticness_%": 17, "instrumentalness_%": 0, "liveness_%": 31, '
#              '"speechiness_%": 6, "album": NaN, "explicit": NaN, "popularity": '
#              'NaN, "duration_in_min": NaN}, {"track_name": "good 4 u", '
#              '"artist(s)_name": "Olivia Rodrigo", "artist_count": 1, '
#              '"release_date": "2021-05-14", "streams": "1887039593", "bpm": '
#              '166, "key": "F#", "mode": "Minor", "danceability_%": 56, '
#              '"valence_%": 68, "energy_%": 66, "acousticness_%": 28, '
#              '"instrumentalness_%": 0, "liveness_%": 11, "speechiness_%": 18, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "drivers license", '
#              '"artist(s)_name": "Olivia Rodrigo", "artist_count": 1, '
#              '"release_date": "2021-01-08", "streams": "1858144199", "bpm": '
#              '144, "key": "A#", "mode": "Major", "danceability_%": 59, '
#              '"valence_%": 21, "energy_%": 43, "acousticness_%": 76, '
#              '"instrumentalness_%": 0, "liveness_%": 10, "speechiness_%": 7, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "deja vu", '
#              '"artist(s)_name": "Olivia Rodrigo", "artist_count": 1, '
#              '"release_date": "2021-04-01", "streams": "1256880657", "bpm": '
#              '181, "key": "A", "mode": "Major", "danceability_%": 44, '
#              '"valence_%": 22, "energy_%": 60, "acousticness_%": 61, '
#              '"instrumentalness_%": 0, "liveness_%": 42, "speechiness_%": 9, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "happier", '
#              '"artist(s)_name": "Olivia Rodrigo", "artist_count": 1, '
#              '"release_date": "2021-05-21", "streams": "850608354", "bpm": '
#              '169, "key": "F#", "mode": "Major", "danceability_%": 39, '
#              '"valence_%": 36, "energy_%": 45, "acousticness_%": 81, '
#              '"instrumentalness_%": 0, "liveness_%": 8, "speechiness_%": 13, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "favorite crime", '
#              '"artist(s)_name": "Olivia Rodrigo", "artist_count": 1, '
#              '"release_date": "2021-05-21", "streams": "783706581", "bpm": '
#              '173, "key": "A", "mode": "Major", "danceability_%": 40, '
#              '"valence_%": 19, "energy_%": 29, "acousticness_%": 86, '
#              '"instrumentalness_%": 0, "liveness_%": 34, "speechiness_%": 4, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "jealousy, jealousy", '
#              '"artist(s)_name": "Olivia Rodrigo", "artist_count": 1, '
#              '"release_date": "2021-05-21", "streams": "665765558", "bpm": '
#              '164, "key": "A#", "mode": "Minor", "danceability_%": 70, '
#              '"valence_%": 71, "energy_%": 58, "acousticness_%": 24, '
#              '"instrumentalness_%": 0, "liveness_%": 7, "speechiness_%": 13, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}]',
#   'name': 'songs_by_artist',
#   'role': 'function'},
#  {'content': "The average value of beats per minute for Olivia Rodrigo's songs "
#              'is approximately 160.',
#   'role': 'assistant'}]

# %% [markdown]
# # REASONING QUESTIONS

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "Provide me the albums of Pink Floyd whose title starts with the word ‘The’."}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# The albums of Pink Floyd whose title starts with the word 'The' are:
# 1. The Dark Side of the Moon
# 2. The Wall
# 3. The Final Cut

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'Provide me the albums of Pink Floyd whose title starts with the '
#              'word ‘The’.',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "artist_name": "Pink Floyd"\n}',
#                     'name': 'albums_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "The Dark Side of the Moon", "artist_name": '
#              '"Pink Floyd", "release_date": "1973-03-23", "genres": "Space '
#              'Rock, Psychedelic Rock, Progressive Rock, Art Rock", '
#              '"descriptors": "philosophical, atmospheric, introspective, '
#              'existential, mellow, conceptalbum, malevocals, psychedelic, '
#              'progressive, epic", "avg_rating": 4.21, "rating_count": 60192, '
#              '"review_count": 1557.0}, {"release_name": "Wish You Were Here", '
#              '"artist_name": "Pink Floyd", "release_date": "1975-09-12", '
#              '"genres": "Space Rock, Psychedelic Rock, Progressive Rock, Art '
#              'Rock", "descriptors": "melancholic, atmospheric, progressive, '
#              'malevocals, conceptalbum, serious, introspective, longing, '
#              'alienation, bittersweet", "avg_rating": 4.3, "rating_count": '
#              '51246, "review_count": 1006.0}, {"release_name": "The Wall", '
#              '"artist_name": "Pink Floyd", "release_date": "1979-11-30", '
#              '"genres": "Symphonic Rock, Progressive Rock, Rock Opera, Art '
#              'Rock", "descriptors": "rockopera, misanthropic, lonely, '
#              'conceptalbum, introspective, anxious, dark, epic, malevocals, '
#              'alienation", "avg_rating": 3.81, "rating_count": 38350, '
#              '"review_count": 752.0}, {"release_name": "Animals", '
#              '"artist_name": "Pink Floyd", "release_date": "1977-01-21", '
#              '"genres": "Psychedelic Rock, Progressive Rock, Art Rock", '
#              '"descriptors": "political, pessimistic, philosophical, '
#              'conceptalbum, sarcastic, progressive, satirical, malevocals, '
#              'complex, atmospheric", "avg_rating": 4.14, "rating_count": '
#              '38195, "review_count": 704.0}, {"release_name": "The Piper at '
#              'the Gates of Dawn", "artist_name": "Pink Floyd", "release_date": '
#              '"1967-08-04", "genres": "Psychedelic Pop, Space Rock, '
#              'Experimental Rock, Psychedelic Rock", "descriptors": '
#              '"psychedelic, drugs, fantasy, surreal, playful, abstract, '
#              'quirky, malevocals, avant-garde, cryptic", "avg_rating": 3.85, '
#              '"rating_count": 29582, "review_count": 701.0}, {"release_name": '
#              '"Meddle", "artist_name": "Pink Floyd", "release_date": '
#              '"1971-11-05", "genres": "Space Rock, Progressive Rock, Folk '
#              'Rock, Psychedelic Rock", "descriptors": "mellow, psychedelic, '
#              'atmospheric, progressive, mysterious, malevocals, hypnotic, '
#              'calm, surreal, epic", "avg_rating": 3.97, "rating_count": 29047, '
#              '"review_count": 531.0}, {"release_name": "Atom Heart Mother", '
#              '"artist_name": "Pink Floyd", "release_date": "1970-10-02", '
#              '"genres": "Experimental Rock, Psychedelic Rock, Field '
#              'Recordings, Progressive Rock, Folk Rock, Symphonic Prog", '
#              '"descriptors": "psychedelic, peaceful, progressive, suite, '
#              'malevocals, mellow, pastoral, soft, atmospheric, complex", '
#              '"avg_rating": 3.6, "rating_count": 19829, "review_count": '
#              '373.0}, {"release_name": "A Saucerful of Secrets", '
#              '"artist_name": "Pink Floyd", "release_date": "1968-06-29", '
#              '"genres": "Space Rock, Progressive Rock, Experimental Rock, '
#              'Psychedelic Rock", "descriptors": "psychedelic, surreal, '
#              'mysterious, space, atmospheric, malevocals, avant-garde, '
#              'hypnotic, progressive, abstract", "avg_rating": 3.63, '
#              '"rating_count": 17855, "review_count": 320.0}, {"release_name": '
#              '"The Division Bell", "artist_name": "Pink Floyd", '
#              '"release_date": "1994-03-28", "genres": "Space Rock, Progressive '
#              'Rock, New Age, Art Rock", "descriptors": "introspective, mellow, '
#              'malevocals, peaceful, melancholic, atmospheric, bittersweet, '
#              'philosophical, serious, soft", "avg_rating": 3.24, '
#              '"rating_count": 14110, "review_count": 291.0}, {"release_name": '
#              '"Ummagumma", "artist_name": "Pink Floyd", "release_date": '
#              '"1969-11-07", "genres": "Space Rock, Experimental Rock, '
#              'Psychedelic Rock, Musiqueconcr\\u00e8te, Progressive Rock, '
#              'Experimental", "descriptors": "psychedelic, cryptic, '
#              'avant-garde, eclectic, malevocals, dissonant, atmospheric, '
#              'ominous, chaotic, surreal", "avg_rating": 3.19, "rating_count": '
#              '13429, "review_count": 307.0}, {"release_name": "The Final Cut", '
#              '"artist_name": "Pink Floyd", "release_date": "1983-03-21", '
#              '"genres": "Symphonic Rock, Art Rock", "descriptors": "war, '
#              'political, sad, misanthropic, conceptalbum, malevocals, '
#              'philosophical, pessimistic, melancholic, death", "avg_rating": '
#              '3.01, "rating_count": 12081, "review_count": 337.0}, '
#              '{"release_name": "Obscured by Clouds", "artist_name": "Pink '
#              'Floyd", "release_date": "1972-06-02", "genres": "Film '
#              'Soundtrack, Progressive Rock, Hard Rock, Psychedelic Rock", '
#              '"descriptors": "psychedelic, mellow, atmospheric, malevocals, '
#              'progressive, warm, meditative, pastoral, introspective, '
#              'philosophical", "avg_rating": 3.34, "rating_count": 10916, '
#              '"review_count": 228.0}, {"release_name": "A Momentary Lapse of '
#              'Reason", "artist_name": "Pink Floyd", "release_date": '
#              '"1987-09-07", "genres": "Pop Rock, Progressive Rock, AOR, Art '
#              'Rock", "descriptors": "melodic, malevocals, atmospheric, soft, '
#              'cold, uplifting, existential, mellow", "avg_rating": 2.77, '
#              '"rating_count": 10544, "review_count": 196.0}, {"release_name": '
#              '"The Endless River", "artist_name": "Pink Floyd", '
#              '"release_date": "2014-11-10", "genres": "Ambient, Space Rock, '
#              'New Age, Art Rock", "descriptors": "mellow, instrumental, soft, '
#              'atmospheric, soothing, ethereal, bittersweet, lush, sparse", '
#              '"avg_rating": 2.57, "rating_count": 6417, "review_count": '
#              '119.0}]',
#   'name': 'albums_by_artist',
#   'role': 'function'},
#  {'content': "The albums of Pink Floyd whose title starts with the word 'The' "
#              'are:\n'
#              '1. The Dark Side of the Moon\n'
#              '2. The Wall\n'
#              '3. The Final Cut',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "I consider rating as a parameter of popularity. Can you give me the most popular album of Red Hot Chilli Peppers."}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# The most popular album by Red Hot Chili Peppers is "Californication" with an average rating of 3.48 and a total of 16,401 ratings.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'I consider rating as a parameter of popularity. Can you give me '
#              'the most popular album of Red Hot Chilli Peppers.',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n'
#                                  '  "artist_name": "Red Hot Chili Peppers"\n'
#                                  '}',
#                     'name': 'albums_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "Californication", "artist_name": "Red Hot '
#              'Chili Peppers", "release_date": "1999-06-08", "genres": '
#              '"Alternative Rock, Funk Rock", "descriptors": "summer, '
#              'energetic, melodic, malevocals, playful, introspective, '
#              'bittersweet, eclectic, rhythmic, drugs", "avg_rating": 3.48, '
#              '"rating_count": 16401, "review_count": 286.0}, {"release_name": '
#              '"Blood Sugar Sex Magik", "artist_name": "Red Hot Chili Peppers", '
#              '"release_date": "1991-09-24", "genres": "Rap Rock, Alternative '
#              'Rock, Funk Rock", "descriptors": "sexual, energetic, playful, '
#              'drugs, humorous, vulgar, summer, malevocals, bittersweet, '
#              'rhythmic", "avg_rating": 3.6, "rating_count": 15587, '
#              '"review_count": 343.0}, {"release_name": "By the Way", '
#              '"artist_name": "Red Hot Chili Peppers", "release_date": '
#              '"2002-07-08", "genres": "Pop Rock, Alternative Rock, Funk Rock, '
#              'Psychedelic Rock", "descriptors": "summer, energetic, mellow, '
#              'melodic, malevocals, melancholic, warm, death, love, lush", '
#              '"avg_rating": 3.29, "rating_count": 10552, "review_count": '
#              '250.0}, {"release_name": "Stadium Arcadium", "artist_name": "Red '
#              'Hot Chili Peppers", "release_date": "2006-05-09", "genres": "Pop '
#              'Rock, Alternative Rock, Funk Rock", "descriptors": "malevocals, '
#              'energetic, playful, melodic, anthemic, eclectic, melancholic, '
#              'sexual, urban, summer", "avg_rating": 3.01, "rating_count": '
#              '9590, "review_count": 312.0}, {"release_name": "Mother\'s Milk", '
#              '"artist_name": "Red Hot Chili Peppers", "release_date": '
#              '"1989-08-04", "genres": "Rap Rock, Alternative Rock, Funk Rock, '
#              'Funk Metal", "descriptors": "energetic, malevocals, eclectic, '
#              'sexual, hedonistic, playful, rhythmic, humorous, vulgar, '
#              'boastful", "avg_rating": 3.29, "rating_count": 5637, '
#              '"review_count": 115.0}, {"release_name": "I\'m With You", '
#              '"artist_name": "Red Hot Chili Peppers", "release_date": '
#              '"2011-08-29", "genres": "Pop Rock, Alternative Rock, Funk Rock", '
#              '"descriptors": "melodic, energetic, optimistic, malevocals, '
#              'love", "avg_rating": 2.62, "rating_count": 4139, "review_count": '
#              '85.0}, {"release_name": "The Getaway", "artist_name": "Red Hot '
#              'Chili Peppers", "release_date": "2016-06-17", "genres": "Pop '
#              'Rock, Alternative Rock, Funk Rock", "descriptors": "melodic, '
#              'summer, malevocals, melancholic, playful, bittersweet, '
#              'uplifting, introspective, anthemic, warm", "avg_rating": 2.81, '
#              '"rating_count": 3586, "review_count": 39.0}]',
#   'name': 'albums_by_artist',
#   'role': 'function'},
#  {'content': 'The most popular album by Red Hot Chili Peppers is '
#              '"Californication" with an average rating of 3.48 and a total of '
#              '16,401 ratings.',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "Which songs released in 2012 were performed by more than 1 artist?"}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# The songs released in 2012 that were performed by more than 1 artist are:
# 1. "MONTAGEM - FR PUNK" by Ayparia, unxbected
# 2. "Money Trees" by Kendrick Lamar, Jay Rock
# 3. "Payphone" by Maroon 5, Wiz Khalifa

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'Which songs released in 2012 were performed by more than 1 '
#              'artist?',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "release_date": "2012"\n}',
#                     'name': 'songs_by_release_date'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "Another Love", "artist(s)_name": "Tom Odell", '
#              '"artist_count": 1, "release_date": "2012-10-15", "streams": '
#              '"1813673666", "bpm": 123, "key": "E", "mode": "Minor", '
#              '"danceability_%": 45, "valence_%": 13, "energy_%": 54, '
#              '"acousticness_%": 70, "instrumentalness_%": 0, "liveness_%": 9, '
#              '"speechiness_%": 4, "album": NaN, "explicit": NaN, "popularity": '
#              'NaN, "duration_in_min": NaN}, {"track_name": "Sweater Weather", '
#              '"artist(s)_name": "The Neighbourhood", "artist_count": 1, '
#              '"release_date": "2012-05-14", "streams": "2282771485", "bpm": '
#              '124, "key": "A#", "mode": "Major", "danceability_%": 61, '
#              '"valence_%": 41, "energy_%": 81, "acousticness_%": 5, '
#              '"instrumentalness_%": 2, "liveness_%": 10, "speechiness_%": 3, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "MONTAGEM - FR PUNK", '
#              '"artist(s)_name": "Ayparia, unxbected", "artist_count": 2, '
#              '"release_date": "2012-06-20", "streams": "58054811", "bpm": 129, '
#              '"key": "A", "mode": "Major", "danceability_%": 63, "valence_%": '
#              '84, "energy_%": 82, "acousticness_%": 70, "instrumentalness_%": '
#              '8, "liveness_%": 9, "speechiness_%": 7, "album": NaN, '
#              '"explicit": NaN, "popularity": NaN, "duration_in_min": NaN}, '
#              '{"track_name": "Lover", "artist(s)_name": "Taylor Swift", '
#              '"artist_count": 1, "release_date": "2012-01-01", "streams": '
#              '"882831184", "bpm": 206, "key": "G", "mode": "Major", '
#              '"danceability_%": 43, "valence_%": 50, "energy_%": 55, '
#              '"acousticness_%": 50, "instrumentalness_%": 0, "liveness_%": 15, '
#              '"speechiness_%": 10, "album": NaN, "explicit": NaN, '
#              '"popularity": NaN, "duration_in_min": NaN}, {"track_name": '
#              '"Money Trees", "artist(s)_name": "Kendrick Lamar, Jay Rock", '
#              '"artist_count": 2, "release_date": "2012-01-01", "streams": '
#              '"1093605526", "bpm": 144, "key": "E", "mode": "Minor", '
#              '"danceability_%": 74, "valence_%": 37, "energy_%": 53, '
#              '"acousticness_%": 7, "instrumentalness_%": 0, "liveness_%": 21, '
#              '"speechiness_%": 10, "album": NaN, "explicit": NaN, '
#              '"popularity": NaN, "duration_in_min": NaN}, {"track_name": '
#              '"Locked Out Of Heaven", "artist(s)_name": "Bruno Mars", '
#              '"artist_count": 1, "release_date": "2012-12-05", "streams": '
#              '"1481349984", "bpm": 144, "key": "F", "mode": "Major", '
#              '"danceability_%": 73, "valence_%": 87, "energy_%": 70, '
#              '"acousticness_%": 6, "instrumentalness_%": 0, "liveness_%": 28, '
#              '"speechiness_%": 5, "album": NaN, "explicit": NaN, "popularity": '
#              'NaN, "duration_in_min": NaN}, {"track_name": "When I Was Your '
#              'Man", "artist(s)_name": "Bruno Mars", "artist_count": 1, '
#              '"release_date": "2012-12-05", "streams": "1661187319", "bpm": '
#              '145, "key": NaN, "mode": "Major", "danceability_%": 60, '
#              '"valence_%": 43, "energy_%": 27, "acousticness_%": 94, '
#              '"instrumentalness_%": 0, "liveness_%": 14, "speechiness_%": 4, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Demons", '
#              '"artist(s)_name": "Imagine Dragons", "artist_count": 1, '
#              '"release_date": "2012-01-01", "streams": "1840364617", "bpm": '
#              '180, "key": "D#", "mode": "Major", "danceability_%": 33, '
#              '"valence_%": 38, "energy_%": 71, "acousticness_%": 20, '
#              '"instrumentalness_%": 0, "liveness_%": 28, "speechiness_%": 5, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Payphone", '
#              '"artist(s)_name": "Maroon 5, Wiz Khalifa", "artist_count": 2, '
#              '"release_date": "2012-01-01", "streams": "1479264469", "bpm": '
#              '110, "key": "E", "mode": "Major", "danceability_%": 74, '
#              '"valence_%": 51, "energy_%": 74, "acousticness_%": 2, '
#              '"instrumentalness_%": 0, "liveness_%": 29, "speechiness_%": 4, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}, {"track_name": "Lost", '
#              '"artist(s)_name": "Frank Ocean", "artist_count": 1, '
#              '"release_date": "2012-01-01", "streams": "822239726", "bpm": '
#              '123, "key": "A#", "mode": "Minor", "danceability_%": 91, '
#              '"valence_%": 49, "energy_%": 61, "acousticness_%": 3, '
#              '"instrumentalness_%": 0, "liveness_%": 17, "speechiness_%": 22, '
#              '"album": NaN, "explicit": NaN, "popularity": NaN, '
#              '"duration_in_min": NaN}]',
#   'name': 'songs_by_release_date',
#   'role': 'function'},
#  {'content': 'The songs released in 2012 that were performed by more than 1 '
#              'artist are:\n'
#              '1. "MONTAGEM - FR PUNK" by Ayparia, unxbected\n'
#              '2. "Money Trees" by Kendrick Lamar, Jay Rock\n'
#              '3. "Payphone" by Maroon 5, Wiz Khalifa',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "Get me a list of songs starting with l by Harry Styles."}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# Here are some songs by Harry Styles starting with the letter L:
# 1. Late Night Talking
# 2. Little Freak
# 3. Love Of My Life

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'Get me a list of songs starting with l by Harry Styles.',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "artist_name": "Harry Styles"\n}',
#                     'name': 'songs_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "As It Was", "artist(s)_name": "Harry Styles", '
#              '"artist_count": 1, "released_year": 2022, "released_month": 3, '
#              '"released_day": 31, "in_spotify_playlists": 23575, '
#              '"in_spotify_charts": 130, "streams": "2513188493", '
#              '"in_apple_playlists": 403, "in_apple_charts": 198, '
#              '"in_deezer_playlists": "863", "in_deezer_charts": 46, '
#              '"in_shazam_charts": NaN, "bpm": 174, "key": "F#", "mode": '
#              '"Minor", "danceability_%": 52, "valence_%": 66, "energy_%": 73, '
#              '"acousticness_%": 34, "instrumentalness_%": 0, "liveness_%": 31, '
#              '"speechiness_%": 6}, {"track_name": "Watermelon Sugar", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2019, "released_month": 11, "released_day": 17, '
#              '"in_spotify_playlists": 21915, "in_spotify_charts": 34, '
#              '"streams": "2322580122", "in_apple_playlists": 437, '
#              '"in_apple_charts": 115, "in_deezer_playlists": "1,212", '
#              '"in_deezer_charts": 12, "in_shazam_charts": NaN, "bpm": 95, '
#              '"key": NaN, "mode": "Major", "danceability_%": 55, "valence_%": '
#              '56, "energy_%": 82, "acousticness_%": 12, "instrumentalness_%": '
#              '0, "liveness_%": 34, "speechiness_%": 5}, {"track_name": "Late '
#              'Night Talking", "artist(s)_name": "Harry Styles", '
#              '"artist_count": 1, "released_year": 2022, "released_month": 5, '
#              '"released_day": 20, "in_spotify_playlists": 7461, '
#              '"in_spotify_charts": 8, "streams": "743693613", '
#              '"in_apple_playlists": 166, "in_apple_charts": 42, '
#              '"in_deezer_playlists": "199", "in_deezer_charts": 16, '
#              '"in_shazam_charts": "58", "bpm": 115, "key": "A#", "mode": '
#              '"Major", "danceability_%": 71, "valence_%": 90, "energy_%": 73, '
#              '"acousticness_%": 30, "instrumentalness_%": 0, "liveness_%": 11, '
#              '"speechiness_%": 5}, {"track_name": "Adore You", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2019, "released_month": 12, "released_day": 6, '
#              '"in_spotify_playlists": 13454, "in_spotify_charts": 1, '
#              '"streams": "1439191367", "in_apple_playlists": 246, '
#              '"in_apple_charts": 71, "in_deezer_playlists": "519", '
#              '"in_deezer_charts": 2, "in_shazam_charts": "5", "bpm": 99, '
#              '"key": "G#", "mode": "Major", "danceability_%": 68, "valence_%": '
#              '57, "energy_%": 77, "acousticness_%": 2, "instrumentalness_%": '
#              '0, "liveness_%": 10, "speechiness_%": 5}, {"track_name": '
#              '"Falling", "artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2019, "released_month": 12, "released_day": 13, '
#              '"in_spotify_playlists": 7556, "in_spotify_charts": 0, "streams": '
#              '"1023187129", "in_apple_playlists": 124, "in_apple_charts": 24, '
#              '"in_deezer_playlists": "254", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "8", "bpm": 110, "key": "E", "mode": '
#              '"Major", "danceability_%": 57, "valence_%": 6, "energy_%": 27, '
#              '"acousticness_%": 84, "instrumentalness_%": 0, "liveness_%": 9, '
#              '"speechiness_%": 3}, {"track_name": "Golden", "artist(s)_name": '
#              '"Harry Styles", "artist_count": 1, "released_year": 2019, '
#              '"released_month": 12, "released_day": 13, '
#              '"in_spotify_playlists": 8429, "in_spotify_charts": 1, "streams": '
#              '"807015863", "in_apple_playlists": 85, "in_apple_charts": 24, '
#              '"in_deezer_playlists": "200", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "2", "bpm": 140, "key": "E", "mode": '
#              '"Minor", "danceability_%": 45, "valence_%": 25, "energy_%": 84, '
#              '"acousticness_%": 21, "instrumentalness_%": 0, "liveness_%": 13, '
#              '"speechiness_%": 6}, {"track_name": "Music For a Sushi '
#              'Restaurant", "artist(s)_name": "Harry Styles", "artist_count": '
#              '1, "released_year": 2022, "released_month": 5, "released_day": '
#              '20, "in_spotify_playlists": 4449, "in_spotify_charts": 1, '
#              '"streams": "334733572", "in_apple_playlists": 80, '
#              '"in_apple_charts": 11, "in_deezer_playlists": "66", '
#              '"in_deezer_charts": 0, "in_shazam_charts": "1", "bpm": 107, '
#              '"key": "B", "mode": "Major", "danceability_%": 72, "valence_%": '
#              '36, "energy_%": 72, "acousticness_%": 26, "instrumentalness_%": '
#              '6, "liveness_%": 11, "speechiness_%": 4}, {"track_name": '
#              '"Matilda", "artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 3218, "in_spotify_charts": 3, "streams": '
#              '"366214458", "in_apple_playlists": 29, "in_apple_charts": 10, '
#              '"in_deezer_playlists": "79", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 114, "key": "D", "mode": '
#              '"Major", "danceability_%": 51, "valence_%": 39, "energy_%": 29, '
#              '"acousticness_%": 90, "instrumentalness_%": 0, "liveness_%": 10, '
#              '"speechiness_%": 4}, {"track_name": "Daylight", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 2775, "in_spotify_charts": 0, "streams": '
#              '"290833204", "in_apple_playlists": 21, "in_apple_charts": 11, '
#              '"in_deezer_playlists": "40", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 146, "key": NaN, "mode": '
#              '"Major", "danceability_%": 69, "valence_%": 63, "energy_%": 45, '
#              '"acousticness_%": 48, "instrumentalness_%": 0, "liveness_%": 18, '
#              '"speechiness_%": 4}, {"track_name": "Little Freak", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 2302, "in_spotify_charts": 0, "streams": '
#              '"273194684", "in_apple_playlists": 20, "in_apple_charts": 3, '
#              '"in_deezer_playlists": "39", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 142, "key": "D#", "mode": '
#              '"Major", "danceability_%": 56, "valence_%": 40, "energy_%": 54, '
#              '"acousticness_%": 72, "instrumentalness_%": 0, "liveness_%": 10, '
#              '"speechiness_%": 4}, {"track_name": "Satellite", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 3291, "in_spotify_charts": 5, "streams": '
#              '"311482393", "in_apple_playlists": 43, "in_apple_charts": 28, '
#              '"in_deezer_playlists": "79", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "208", "bpm": 139, "key": NaN, "mode": '
#              '"Major", "danceability_%": 58, "valence_%": 30, "energy_%": 46, '
#              '"acousticness_%": 14, "instrumentalness_%": 0, "liveness_%": 9, '
#              '"speechiness_%": 3}, {"track_name": "Love Of My Life", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 1933, "in_spotify_charts": 0, "streams": '
#              '"233671263", "in_apple_playlists": 13, "in_apple_charts": 2, '
#              '"in_deezer_playlists": "31", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 118, "key": "G", "mode": '
#              '"Major", "danceability_%": 56, "valence_%": 20, "energy_%": 54, '
#              '"acousticness_%": 67, "instrumentalness_%": 0, "liveness_%": 6, '
#              '"speechiness_%": 5}, {"track_name": "Grapejuice", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 1986, "in_spotify_charts": 0, "streams": '
#              '"199587884", "in_apple_playlists": 7, "in_apple_charts": 1, '
#              '"in_deezer_playlists": "15", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 183, "key": "F", "mode": '
#              '"Major", "danceability_%": 65, "valence_%": 88, "energy_%": 72, '
#              '"acousticness_%": 36, "instrumentalness_%": 14, "liveness_%": '
#              '20, "speechiness_%": 3}, {"track_name": "Keep Driving", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 2094, "in_spotify_charts": 1, "streams": '
#              '"236060709", "in_apple_playlists": 8, "in_apple_charts": 1, '
#              '"in_deezer_playlists": "18", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 165, "key": "A", "mode": '
#              '"Major", "danceability_%": 72, "valence_%": 90, "energy_%": 48, '
#              '"acousticness_%": 32, "instrumentalness_%": 0, "liveness_%": 18, '
#              '"speechiness_%": 23}, {"track_name": "Cinema", "artist(s)_name": '
#              '"Harry Styles", "artist_count": 1, "released_year": 2022, '
#              '"released_month": 5, "released_day": 20, "in_spotify_playlists": '
#              '2171, "in_spotify_charts": 0, "streams": "189236868", '
#              '"in_apple_playlists": 18, "in_apple_charts": 1, '
#              '"in_deezer_playlists": "28", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 106, "key": "A", "mode": '
#              '"Minor", "danceability_%": 83, "valence_%": 90, "energy_%": 64, '
#              '"acousticness_%": 35, "instrumentalness_%": 5, "liveness_%": 9, '
#              '"speechiness_%": 4}, {"track_name": "Daydreaming", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 1900, "in_spotify_charts": 1, "streams": '
#              '"187703102", "in_apple_playlists": 15, "in_apple_charts": 1, '
#              '"in_deezer_playlists": "23", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 114, "key": "E", "mode": '
#              '"Minor", "danceability_%": 71, "valence_%": 90, "energy_%": 81, '
#              '"acousticness_%": 31, "instrumentalness_%": 2, "liveness_%": 13, '
#              '"speechiness_%": 3}, {"track_name": "Boyfriends", '
#              '"artist(s)_name": "Harry Styles", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 5, "released_day": 20, '
#              '"in_spotify_playlists": 1517, "in_spotify_charts": 0, "streams": '
#              '"137070925", "in_apple_playlists": 26, "in_apple_charts": 2, '
#              '"in_deezer_playlists": "30", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 118, "key": NaN, "mode": '
#              '"Major", "danceability_%": 42, "valence_%": 32, "energy_%": 20, '
#              '"acousticness_%": 94, "instrumentalness_%": 0, "liveness_%": 11, '
#              '"speechiness_%": 4}]',
#   'name': 'songs_by_artist',
#   'role': 'function'},
#  {'content': 'Here are some songs by Harry Styles starting with the letter L:\n'
#              '1. Late Night Talking\n'
#              '2. Little Freak\n'
#              '3. Love Of My Life',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "Of the top 15 songs in Spotify, return the ones starting with e."}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# Of the top 15 songs in Spotify, the ones starting with "e" are:
#
# 1. "Anti-Hero" by Taylor Swift
# 2. "Everything I Love" by Morgan Wallen

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'Of the top 15 songs in Spotify, return the ones starting with e.',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "n": 15\n}',
#                     'name': 'top_streamed_songs'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "Love Grows (Where My Rosemary Goes)", '
#              '"artist(s)_name": "Edison Lighthouse", "artist_count": 1, '
#              '"released_year": 1970, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 2877, "in_spotify_charts": 0, "streams": '
#              '"BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3", '
#              '"in_apple_playlists": 16, "in_apple_charts": 0, '
#              '"in_deezer_playlists": "54", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 110, "key": "A", "mode": '
#              '"Major", "danceability_%": 53, "valence_%": 75, "energy_%": 69, '
#              '"acousticness_%": 7, "instrumentalness_%": 0, "liveness_%": 17, '
#              '"speechiness_%": 3}, {"track_name": "Anti-Hero", '
#              '"artist(s)_name": "Taylor Swift", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 10, "released_day": 21, '
#              '"in_spotify_playlists": 9082, "in_spotify_charts": 56, '
#              '"streams": "999748277", "in_apple_playlists": 242, '
#              '"in_apple_charts": 142, "in_deezer_playlists": "165", '
#              '"in_deezer_charts": 9, "in_shazam_charts": "310", "bpm": 97, '
#              '"key": "E", "mode": "Major", "danceability_%": 64, "valence_%": '
#              '51, "energy_%": 63, "acousticness_%": 12, "instrumentalness_%": '
#              '0, "liveness_%": 19, "speechiness_%": 5}, {"track_name": '
#              '"Arcade", "artist(s)_name": "Duncan Laurence", "artist_count": '
#              '1, "released_year": 2019, "released_month": 3, "released_day": '
#              '7, "in_spotify_playlists": 6646, "in_spotify_charts": 0, '
#              '"streams": "991336132", "in_apple_playlists": 107, '
#              '"in_apple_charts": 47, "in_deezer_playlists": "584", '
#              '"in_deezer_charts": 1, "in_shazam_charts": NaN, "bpm": 72, '
#              '"key": "A", "mode": "Minor", "danceability_%": 45, "valence_%": '
#              '27, "energy_%": 33, "acousticness_%": 82, "instrumentalness_%": '
#              '0, "liveness_%": 14, "speechiness_%": 4}, {"track_name": '
#              '"Glimpse of Us", "artist(s)_name": "Joji", "artist_count": 1, '
#              '"released_year": 2022, "released_month": 6, "released_day": 10, '
#              '"in_spotify_playlists": 6330, "in_spotify_charts": 6, "streams": '
#              '"988515741", "in_apple_playlists": 109, "in_apple_charts": 42, '
#              '"in_deezer_playlists": "158", "in_deezer_charts": 3, '
#              '"in_shazam_charts": "31", "bpm": 170, "key": "G#", "mode": '
#              '"Major", "danceability_%": 44, "valence_%": 27, "energy_%": 32, '
#              '"acousticness_%": 89, "instrumentalness_%": 0, "liveness_%": 14, '
#              '"speechiness_%": 5}, {"track_name": "Seek & Destroy", '
#              '"artist(s)_name": "SZA", "artist_count": 1, "released_year": '
#              '2022, "released_month": 12, "released_day": 9, '
#              '"in_spotify_playlists": 1007, "in_spotify_charts": 0, "streams": '
#              '"98709329", "in_apple_playlists": 5, "in_apple_charts": 31, '
#              '"in_deezer_playlists": "1", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 152, "key": "C#", "mode": '
#              '"Major", "danceability_%": 65, "valence_%": 35, "energy_%": 65, '
#              '"acousticness_%": 44, "instrumentalness_%": 18, "liveness_%": '
#              '21, "speechiness_%": 7}, {"track_name": "Summertime Sadness", '
#              '"artist(s)_name": "Lana Del Rey", "artist_count": 1, '
#              '"released_year": 2011, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 20333, "in_spotify_charts": 52, '
#              '"streams": "983637508", "in_apple_playlists": 89, '
#              '"in_apple_charts": 143, "in_deezer_playlists": "1,632", '
#              '"in_deezer_charts": 3, "in_shazam_charts": "200", "bpm": 112, '
#              '"key": "C#", "mode": "Minor", "danceability_%": 56, "valence_%": '
#              '24, "energy_%": 66, "acousticness_%": 7, "instrumentalness_%": '
#              '0, "liveness_%": 12, "speechiness_%": 3}, {"track_name": "Come '
#              'Back Home - From \\"Purple Hearts\\"", "artist(s)_name": "Sofia '
#              'Carson", "artist_count": 1, "released_year": 2022, '
#              '"released_month": 7, "released_day": 12, "in_spotify_playlists": '
#              '367, "in_spotify_charts": 0, "streams": "97610446", '
#              '"in_apple_playlists": 28, "in_apple_charts": 67, '
#              '"in_deezer_playlists": "195", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 145, "key": "G", "mode": '
#              '"Major", "danceability_%": 56, "valence_%": 43, "energy_%": 53, '
#              '"acousticness_%": 24, "instrumentalness_%": 0, "liveness_%": 12, '
#              '"speechiness_%": 4}, {"track_name": "Where Are You Now", '
#              '"artist(s)_name": "Lost Frequencies, Calum Scott", '
#              '"artist_count": 2, "released_year": 2021, "released_month": 7, '
#              '"released_day": 30, "in_spotify_playlists": 10565, '
#              '"in_spotify_charts": 44, "streams": "972509632", '
#              '"in_apple_playlists": 238, "in_apple_charts": 122, '
#              '"in_deezer_playlists": "557", "in_deezer_charts": 17, '
#              '"in_shazam_charts": "58", "bpm": 121, "key": "F#", "mode": '
#              '"Minor", "danceability_%": 67, "valence_%": 26, "energy_%": 64, '
#              '"acousticness_%": 52, "instrumentalness_%": 0, "liveness_%": 17, '
#              '"speechiness_%": 10}, {"track_name": "I Love You So", '
#              '"artist(s)_name": "The Walters", "artist_count": 1, '
#              '"released_year": 2014, "released_month": 11, "released_day": 28, '
#              '"in_spotify_playlists": 7536, "in_spotify_charts": 7, "streams": '
#              '"972164968", "in_apple_playlists": 44, "in_apple_charts": 19, '
#              '"in_deezer_playlists": "135", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "6", "bpm": 76, "key": "A#", "mode": '
#              '"Major", "danceability_%": 58, "valence_%": 46, "energy_%": 67, '
#              '"acousticness_%": 65, "instrumentalness_%": 0, "liveness_%": 13, '
#              '"speechiness_%": 4}, {"track_name": "Queencard", '
#              '"artist(s)_name": "(G)I-DLE", "artist_count": 1, '
#              '"released_year": 2023, "released_month": 5, "released_day": 15, '
#              '"in_spotify_playlists": 451, "in_spotify_charts": 33, "streams": '
#              '"96273746", "in_apple_playlists": 10, "in_apple_charts": 126, '
#              '"in_deezer_playlists": "7", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "148", "bpm": 130, "key": "E", "mode": '
#              '"Minor", "danceability_%": 82, "valence_%": 69, "energy_%": 83, '
#              '"acousticness_%": 3, "instrumentalness_%": 0, "liveness_%": 27, '
#              '"speechiness_%": 5}, {"track_name": "Double Fantasy (with '
#              'Future)", "artist(s)_name": "The Weeknd, Future", '
#              '"artist_count": 2, "released_year": 2023, "released_month": 4, '
#              '"released_day": 21, "in_spotify_playlists": 1169, '
#              '"in_spotify_charts": 0, "streams": "96180277", '
#              '"in_apple_playlists": 36, "in_apple_charts": 65, '
#              '"in_deezer_playlists": "28", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 119, "key": "A", "mode": '
#              '"Minor", "danceability_%": 60, "valence_%": 10, "energy_%": 57, '
#              '"acousticness_%": 1, "instrumentalness_%": 0, "liveness_%": 50, '
#              '"speechiness_%": 3}, {"track_name": "Alone", "artist(s)_name": '
#              '"Burna Boy", "artist_count": 1, "released_year": 2022, '
#              '"released_month": 11, "released_day": 4, "in_spotify_playlists": '
#              '782, "in_spotify_charts": 2, "streams": "96007391", '
#              '"in_apple_playlists": 27, "in_apple_charts": 18, '
#              '"in_deezer_playlists": "32", "in_deezer_charts": 1, '
#              '"in_shazam_charts": "0", "bpm": 90, "key": "E", "mode": "Minor", '
#              '"danceability_%": 61, "valence_%": 32, "energy_%": 67, '
#              '"acousticness_%": 15, "instrumentalness_%": 0, "liveness_%": 11, '
#              '"speechiness_%": 5}, {"track_name": "People Pt.2 (feat. IU)", '
#              '"artist(s)_name": "IU, Agust D", "artist_count": 2, '
#              '"released_year": 2023, "released_month": 4, "released_day": 7, '
#              '"in_spotify_playlists": 209, "in_spotify_charts": 4, "streams": '
#              '"95816024", "in_apple_playlists": 4, "in_apple_charts": 45, '
#              '"in_deezer_playlists": "11", "in_deezer_charts": 2, '
#              '"in_shazam_charts": "24", "bpm": 89, "key": "G", "mode": '
#              '"Minor", "danceability_%": 73, "valence_%": 44, "energy_%": 57, '
#              '"acousticness_%": 39, "instrumentalness_%": 0, "liveness_%": 32, '
#              '"speechiness_%": 6}, {"track_name": "No Lie", "artist(s)_name": '
#              '"Sean Paul, Dua Lipa", "artist_count": 2, "released_year": 2016, '
#              '"released_month": 11, "released_day": 18, '
#              '"in_spotify_playlists": 7370, "in_spotify_charts": 0, "streams": '
#              '"956865266", "in_apple_playlists": 92, "in_apple_charts": 127, '
#              '"in_deezer_playlists": "1,219", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "62", "bpm": 102, "key": "G", "mode": '
#              '"Major", "danceability_%": 74, "valence_%": 45, "energy_%": 89, '
#              '"acousticness_%": 5, "instrumentalness_%": 0, "liveness_%": 26, '
#              '"speechiness_%": 13}, {"track_name": "Everything I Love", '
#              '"artist(s)_name": "Morgan Wallen", "artist_count": 1, '
#              '"released_year": 2023, "released_month": 1, "released_day": 31, '
#              '"in_spotify_playlists": 579, "in_spotify_charts": 0, "streams": '
#              '"95623148", "in_apple_playlists": 11, "in_apple_charts": 54, '
#              '"in_deezer_playlists": "0", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "103", "bpm": 104, "key": "G#", "mode": '
#              '"Major", "danceability_%": 56, "valence_%": 72, "energy_%": 85, '
#              '"acousticness_%": 0, "instrumentalness_%": 0, "liveness_%": 15, '
#              '"speechiness_%": 3}]',
#   'name': 'top_streamed_songs',
#   'role': 'function'},
#  {'content': 'Of the top 15 songs in Spotify, the ones starting with "e" are:\n'
#              '\n'
#              '1. "Anti-Hero" by Taylor Swift\n'
#              '2. "Everything I Love" by Morgan Wallen',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "Provide me the songs released in 2011 which are about Christmas."}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# Here are some songs released in 2011 that are about Christmas:
#
# 1. "It's Beginning To Look A Lot Like Christmas" by Michael Bublé
# 2. "Holly Jolly Christmas" by Michael Bublé
# 3. "Mistletoe" by Justin Bieber
#
# Please note that these are just a few examples and there may be more Christmas songs released in 2011.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'Provide me the songs released in 2011 which are about Christmas.',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "year": 2011\n}',
#                     'name': 'songs_by_release_year'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "Summertime Sadness", "artist(s)_name": "Lana '
#              'Del Rey", "artist_count": 1, "released_year": 2011, '
#              '"released_month": 1, "released_day": 1, "in_spotify_playlists": '
#              '20333, "in_spotify_charts": 52, "streams": "983637508", '
#              '"in_apple_playlists": 89, "in_apple_charts": 143, '
#              '"in_deezer_playlists": "1,632", "in_deezer_charts": 3, '
#              '"in_shazam_charts": "200", "bpm": 112, "key": "C#", "mode": '
#              '"Minor", "danceability_%": 56, "valence_%": 24, "energy_%": 66, '
#              '"acousticness_%": 7, "instrumentalness_%": 0, "liveness_%": 12, '
#              '"speechiness_%": 3}, {"track_name": "Set Fire to the Rain", '
#              '"artist(s)_name": "Adele", "artist_count": 1, "released_year": '
#              '2011, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 14739, "in_spotify_charts": 43, '
#              '"streams": "1163620694", "in_apple_playlists": 88, '
#              '"in_apple_charts": 112, "in_deezer_playlists": "2,163", '
#              '"in_deezer_charts": 5, "in_shazam_charts": "519", "bpm": 108, '
#              '"key": "D", "mode": "Minor", "danceability_%": 61, "valence_%": '
#              '47, "energy_%": 68, "acousticness_%": 0, "instrumentalness_%": '
#              '0, "liveness_%": 13, "speechiness_%": 3}, {"track_name": "Can\'t '
#              'Hold Us (feat. Ray Dalton)", "artist(s)_name": "Ray Dalton, Ryan '
#              'Lewis, Macklemore", "artist_count": 3, "released_year": 2011, '
#              '"released_month": 8, "released_day": 16, "in_spotify_playlists": '
#              '6074, "in_spotify_charts": 52, "streams": "1953533826", '
#              '"in_apple_playlists": 201, "in_apple_charts": 44, '
#              '"in_deezer_playlists": "6,551", "in_deezer_charts": 2, '
#              '"in_shazam_charts": "0", "bpm": 146, "key": "D", "mode": '
#              '"Major", "danceability_%": 63, "valence_%": 88, "energy_%": 93, '
#              '"acousticness_%": 3, "instrumentalness_%": 0, "liveness_%": 10, '
#              '"speechiness_%": 8}, {"track_name": "Radio", "artist(s)_name": '
#              '"Lana Del Rey", "artist_count": 1, "released_year": 2011, '
#              '"released_month": 1, "released_day": 1, "in_spotify_playlists": '
#              '9389, "in_spotify_charts": 46, "streams": "284819874", '
#              '"in_apple_playlists": 24, "in_apple_charts": 122, '
#              '"in_deezer_playlists": "282", "in_deezer_charts": 3, '
#              '"in_shazam_charts": "368", "bpm": 150, "key": "D", "mode": '
#              '"Major", "danceability_%": 42, "valence_%": 20, "energy_%": 86, '
#              '"acousticness_%": 21, "instrumentalness_%": 0, "liveness_%": 9, '
#              '"speechiness_%": 9}, {"track_name": "We Found Love", '
#              '"artist(s)_name": "Rihanna, Calvin Harris", "artist_count": 2, '
#              '"released_year": 2011, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 36843, "in_spotify_charts": 21, '
#              '"streams": "1235005533", "in_apple_playlists": 321, '
#              '"in_apple_charts": 91, "in_deezer_playlists": "4,607", '
#              '"in_deezer_charts": 1, "in_shazam_charts": "58", "bpm": 128, '
#              '"key": "C#", "mode": "Major", "danceability_%": 73, "valence_%": '
#              '60, "energy_%": 77, "acousticness_%": 3, "instrumentalness_%": '
#              '0, "liveness_%": 11, "speechiness_%": 4}, {"track_name": "Bloody '
#              'Mary", "artist(s)_name": "Lady Gaga", "artist_count": 1, '
#              '"released_year": 2011, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 3909, "in_spotify_charts": 0, "streams": '
#              '"372476382", "in_apple_playlists": 66, "in_apple_charts": 26, '
#              '"in_deezer_playlists": "277", "in_deezer_charts": 3, '
#              '"in_shazam_charts": "734", "bpm": 100, "key": "A", "mode": '
#              '"Minor", "danceability_%": 59, "valence_%": 49, "energy_%": 65, '
#              '"acousticness_%": 2, "instrumentalness_%": 0, "liveness_%": 13, '
#              '"speechiness_%": 3}, {"track_name": "It\'s Beginning To Look A '
#              'Lot Like Christmas", "artist(s)_name": "Michael Bubl", '
#              '"artist_count": 1, "released_year": 2011, "released_month": 10, '
#              '"released_day": 14, "in_spotify_playlists": 12353, '
#              '"in_spotify_charts": 0, "streams": "807561936", '
#              '"in_apple_playlists": 35, "in_apple_charts": 0, '
#              '"in_deezer_playlists": "549", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 93, "key": "E", "mode": "Major", '
#              '"danceability_%": 35, "valence_%": 38, "energy_%": 23, '
#              '"acousticness_%": 91, "instrumentalness_%": 0, "liveness_%": 29, '
#              '"speechiness_%": 3}, {"track_name": "Holly Jolly Christmas", '
#              '"artist(s)_name": "Michael Bubl", "artist_count": 1, '
#              '"released_year": 2011, "released_month": 10, "released_day": 14, '
#              '"in_spotify_playlists": 7655, "in_spotify_charts": 0, "streams": '
#              '"476244795", "in_apple_playlists": 5, "in_apple_charts": 0, '
#              '"in_deezer_playlists": "291", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 151, "key": "G", "mode": '
#              '"Major", "danceability_%": 65, "valence_%": 70, "energy_%": 47, '
#              '"acousticness_%": 87, "instrumentalness_%": 0, "liveness_%": 9, '
#              '"speechiness_%": 4}, {"track_name": "Mistletoe", '
#              '"artist(s)_name": "Justin Bieber", "artist_count": 1, '
#              '"released_year": 2011, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 9577, "in_spotify_charts": 0, "streams": '
#              '"629173063", "in_apple_playlists": 195, "in_apple_charts": 111, '
#              '"in_deezer_playlists": "310", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 162, "key": "F#", "mode": '
#              '"Minor", "danceability_%": 67, "valence_%": 88, "energy_%": 54, '
#              '"acousticness_%": 51, "instrumentalness_%": 0, "liveness_%": 9, '
#              '"speechiness_%": 4}, {"track_name": "Somebody That I Used To '
#              'Know", "artist(s)_name": "Gotye, Kimbra", "artist_count": 2, '
#              '"released_year": 2011, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 42798, "in_spotify_charts": 0, '
#              '"streams": "1457139296", "in_apple_playlists": 217, '
#              '"in_apple_charts": 136, "in_deezer_playlists": "6,508", '
#              '"in_deezer_charts": 1, "in_shazam_charts": NaN, "bpm": 129, '
#              '"key": NaN, "mode": "Major", "danceability_%": 86, "valence_%": '
#              '75, "energy_%": 52, "acousticness_%": 54, "instrumentalness_%": '
#              '0, "liveness_%": 10, "speechiness_%": 4}]',
#   'name': 'songs_by_release_year',
#   'role': 'function'},
#  {'content': 'Here are some songs released in 2011 that are about Christmas:\n'
#              '\n'
#              '1. "It\'s Beginning To Look A Lot Like Christmas" by Michael '
#              'Bublé\n'
#              '2. "Holly Jolly Christmas" by Michael Bublé\n'
#              '3. "Mistletoe" by Justin Bieber\n'
#              '\n'
#              'Please note that these are just a few examples and there may be '
#              'more Christmas songs released in 2011.',
#   'role': 'assistant'}]

# %% [markdown]
# ## TESTING DATE FORMATS

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. Answer the question briefly."}) \
            .add({"role": Role.USER.value, "content": "Which albums were released on 8th October, 1980?"})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# Two albums were released on 8th October, 1980:
#
# 1. "Remain in Light" by Talking Heads. Genre: Afrobeat, Experimental Rock, Funk, New Wave, Post-Punk, Dance-Punk. Descriptors: rhythmic, anxious, energetic, malevocals, playful, cryptic, abstract, repetitive, quirky, philosophical. Average rating: 4.25. Rating count: 38,220. Review count: 532.
#
# 2. "Dirty Mind" by Prince. Genre: Dance-Pop, Contemporary R&B, Synth Funk, Disco, New Wave. Descriptors: sexual, vulgar, playful, rhythmic, energetic, party, malevocals, hedonistic, sensual, androgynousvocals. Average rating: 3.83. Rating count: 6,594. Review count: 140.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'Which albums were released on 8th October, 1980?',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "release_date": "1980-10-08"\n}',
#                     'name': 'albums_by_release_date'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "Remain in Light", "artist_name": "Talking '
#              'Heads", "release_date": "1980-10-08", "genres": "Afrobeat, '
#              'Experimental Rock, Funk, New Wave, Post-Punk, Dance-Punk", '
#              '"descriptors": "rhythmic, anxious, energetic, malevocals, '
#              'playful, cryptic, abstract, repetitive, quirky, philosophical", '
#              '"avg_rating": 4.25, "rating_count": 38220, "review_count": '
#              '532.0}, {"release_name": "Dirty Mind", "artist_name": "Prince", '
#              '"release_date": "1980-10-08", "genres": "Dance-Pop, Contemporary '
#              'R&B, Synth Funk, Disco, New Wave", "descriptors": "sexual, '
#              'vulgar, playful, rhythmic, energetic, party, malevocals, '
#              'hedonistic, sensual, androgynousvocals", "avg_rating": 3.83, '
#              '"rating_count": 6594, "review_count": 140.0}]',
#   'name': 'albums_by_release_date',
#   'role': 'function'},
#  {'content': 'Two albums were released on 8th October, 1980:\n'
#              '\n'
#              '1. "Remain in Light" by Talking Heads. Genre: Afrobeat, '
#              'Experimental Rock, Funk, New Wave, Post-Punk, Dance-Punk. '
#              'Descriptors: rhythmic, anxious, energetic, malevocals, playful, '
#              'cryptic, abstract, repetitive, quirky, philosophical. Average '
#              'rating: 4.25. Rating count: 38,220. Review count: 532.\n'
#              '\n'
#              '2. "Dirty Mind" by Prince. Genre: Dance-Pop, Contemporary R&B, '
#              'Synth Funk, Disco, New Wave. Descriptors: sexual, vulgar, '
#              'playful, rhythmic, energetic, party, malevocals, hedonistic, '
#              'sensual, androgynousvocals. Average rating: 3.83. Rating count: '
#              '6,594. Review count: 140.',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. Answer the question briefly."}) \
            .add({"role": Role.USER.value, "content": "Provide me the list of albums published on 18/06/2013."})

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# Here is a list of albums published on 18/06/2013:
#
# 1. "Yeezus" by Kanye West
#    - Genres: Industrial Hip Hop, Hardcore Hip Hop, Electro-Industrial, Experimental Hip Hop
#    - Descriptors: vulgar, aggressive, manic, boastful, sampling, noisy, angry, energetic, malevocals, sexual
#    - Average Rating: 3.78
#    - Rating Count: 40,229
#    - Review Count: 389
#
# 2. "Whenever, If Ever" by The World Is a Beautiful Place & I Am No Longer Afraid to Die
#    - Genres: Midwest Emo, Post-Rock
#    - Descriptors: anxious, melancholic, bittersweet, energetic, passionate, poetic, summer, uplifting, melodic, atmospheric
#    - Average Rating: 3.44
#    - Rating Count: 5,256
#    - Review Count: 48
#
# 3. "Watching Movies With the Sound Off" by Mac Miller
#    - Genres: Conscious Hip Hop, Abstract Hip Hop, Cloud Rap, Boom Bap, Pop Rap
#    - Descriptors: drugs, psychedelic, abstract, introspective, melancholic, depressive, malevocals, philosophical, existential, ethereal
#    - Average Rating: 3.42
#    - Rating Count: 4,546
#    - Review Count: 28
#
# 4. "Born Sinner" by J. Cole
#    - Genres: Pop Rap, Conscious Hip Hop, Hip Hop, East Coast Hip Hop
#    - Descriptors: conscious, introspective, serious, love, passionate, sentimental, boastful, rhythmic, malevocals
#    - Average Rating: 2.84
#    - Rating Count: 3,589
#    - Review Count: 34

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'Provide me the list of albums published on 18/06/2013.',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "release_date": "2013-06-18"\n}',
#                     'name': 'albums_by_release_date2'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "Yeezus", "artist_name": "Kanye West", '
#              '"release_date": "2013-06-18", "primary_genres": "Experimental '
#              'Hip Hop, Industrial Hip Hop", "secondary_genres": "Industrial '
#              'Hip Hop, Hardcore Hip Hop, Electro-Industrial", "descriptors": '
#              '"vulgar, aggressive, manic, boastful, sampling, noisy, angry, '
#              'energetic, malevocals, sexual", "avg_rating": 3.78, '
#              '"rating_count": 40229, "review_count": 389}, {"release_name": '
#              '"Whenever, If Ever", "artist_name": "The World Is a Beautiful '
#              'Place & I Am No Longer Afraid to Die", "release_date": '
#              '"2013-06-18", "primary_genres": "Midwest Emo", '
#              '"secondary_genres": "Post-Rock", "descriptors": "anxious, '
#              'melancholic, bittersweet, energetic, passionate, poetic, summer, '
#              'uplifting, melodic, atmospheric", "avg_rating": 3.44, '
#              '"rating_count": 5256, "review_count": 48}, {"release_name": '
#              '"Watching Movies With the Sound Off", "artist_name": "Mac '
#              'Miller", "release_date": "2013-06-18", "primary_genres": '
#              '"Abstract Hip Hop, Cloud Rap", "secondary_genres": "Pop Rap, '
#              'Conscious Hip Hop, Boom Bap", "descriptors": "drugs, '
#              'psychedelic, abstract, introspective, melancholic, depressive, '
#              'malevocals, philosophical, existential, ethereal", "avg_rating": '
#              '3.42, "rating_count": 4546, "review_count": 28}, '
#              '{"release_name": "Born Sinner", "artist_name": "J. Cole", '
#              '"release_date": "2013-06-18", "primary_genres": "Hip Hop, East '
#              'Coast Hip Hop", "secondary_genres": "Conscious Hip Hop, Pop '
#              'Rap", "descriptors": "conscious, introspective, serious, love, '
#              'passionate, sentimental, boastful, rhythmic, malevocals", '
#              '"avg_rating": 2.84, "rating_count": 3589, "review_count": 34}]',
#   'name': 'albums_by_release_date2',
#   'role': 'function'},
#  {'content': 'Here is the list of albums published on 18/06/2013:\n'
#              '\n'
#              '1. Album: Yeezus\n'
#              '   Artist: Kanye West\n'
#              '   Genres: Experimental Hip Hop, Industrial Hip Hop\n'
#              '   Descriptors: vulgar, aggressive, manic, boastful, sampling, '
#              'noisy, angry, energetic, malevocals, sexual\n'
#              '   Average Rating: 3.78\n'
#              '   Rating Count: 40,229\n'
#              '   Review Count: 389\n'
#              '\n'
#              '2. Album: Whenever, If Ever\n'
#              '   Artist: The World Is a Beautiful Place & I Am No Longer '
#              'Afraid to Die\n'
#              '   Genres: Midwest Emo\n'
#              '   Descriptors: anxious, melancholic, bittersweet, energetic, '
#              'passionate, poetic, summer, uplifting, melodic, atmospheric\n'
#              '   Average Rating: 3.44\n'
#              '   Rating Count: 5,256\n'
#              '   Review Count: 48\n'
#              '\n'
#              '3. Album: Watching Movies With the Sound Off\n'
#              '   Artist: Mac Miller\n'
#              '   Genres: Abstract Hip Hop, Cloud Rap\n'
#              '   Descriptors: drugs, psychedelic, abstract, introspective, '
#              'melancholic, depressive, malevocals, philosophical, existential, '
#              'ethereal\n'
#              '   Average Rating: 3.42\n'
#              '   Rating Count: 4,546\n'
#              '   Review Count: 28\n'
#              '\n'
#              '4. Album: Born Sinner\n'
#              '   Artist: J. Cole\n'
#              '   Genres: Hip Hop, East Coast Hip Hop\n'
#              '   Descriptors: conscious, introspective, serious, love, '
#              'passionate, sentimental, boastful, rhythmic, malevocals\n'
#              '   Average Rating: 2.84\n'
#              '   Rating Count: 3,589\n'
#              '   Review Count: 34',
#   'role': 'assistant'}]

# %% [markdown]
# ## QUESTIONS IN DIFFERENT LANGUAGES

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "'Können Sie uns bitte die fünf besten Alben basierend auf der durchschnittlichen Bewertung nennen?"}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# Die fünf besten Alben basierend auf der durchschnittlichen Bewertung sind:
#
# 1. "The Black Saint and the Sinner Lady" von Mingus
# 2. "Wish You Were Here" von Pink Floyd
# 3. "To Pimp a Butterfly" von Kendrick Lamar
# 4. "A Love Supreme" von John Coltrane
# 5. "In the Court of the Crimson King" von King Crimson

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': "'Können Sie uns bitte die fünf besten Alben basierend auf der "
#              'durchschnittlichen Bewertung nennen?',
#   'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "n": 5\n}',
#                     'name': 'top_rated_albums'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "The Black Saint and the Sinner Lady", '
#              '"artist_name": "Mingus", "release_date": "1963-07-01", '
#              '"primary_genres": "Avant-Garde Jazz, Third Stream", '
#              '"secondary_genres": "Experimental Big Band, Flamenco Jazz", '
#              '"descriptors": "instrumental, complex, passionate, suite, dense, '
#              'avant-garde, suspenseful, technical, conceptalbum, manic", '
#              '"avg_rating": 4.34, "rating_count": 21489, "review_count": 369}, '
#              '{"release_name": "Wish You Were Here", "artist_name": "Pink '
#              'Floyd", "release_date": "1975-09-12", "primary_genres": '
#              '"Progressive Rock, Art Rock", "secondary_genres": "Space Rock, '
#              'Psychedelic Rock", "descriptors": "melancholic, atmospheric, '
#              'progressive, malevocals, conceptalbum, serious, introspective, '
#              'longing, alienation, bittersweet", "avg_rating": 4.3, '
#              '"rating_count": 51246, "review_count": 1006}, {"release_name": '
#              '"To Pimp a Butterfly", "artist_name": "Kendrick Lamar", '
#              '"release_date": "2015-03-15", "primary_genres": "Conscious Hip '
#              'Hop, West Coast Hip Hop, Jazz Rap", "secondary_genres": '
#              '"Political Hip Hop, Neo-Soul, Funk, Poetry, Experimental Hip '
#              'Hop", "descriptors": "political, conscious, poetic, '
#              'conceptalbum, protest, introspective, urban, malevocals, '
#              'eclectic, passionate", "avg_rating": 4.3, "rating_count": 47821, '
#              '"review_count": 415}, {"release_name": "A Love Supreme", '
#              '"artist_name": "John Coltrane", "release_date": "1965-02-01", '
#              '"primary_genres": "Spiritual Jazz", "secondary_genres": "Modal '
#              'Jazz, Post-Bop", "descriptors": "improvisation, passionate, '
#              'spiritual, instrumental, complex, suite, acoustic, meditative, '
#              'avant-garde, religious", "avg_rating": 4.3, "rating_count": '
#              '26404, "review_count": 441}, {"release_name": "In the Court of '
#              'the Crimson King", "artist_name": "King Crimson", '
#              '"release_date": "1969-10-10", "primary_genres": "Progressive '
#              'Rock, Art Rock", "secondary_genres": "Symphonic Prog, Jazz-Rock, '
#              'Free Improvisation, Psychedelic Rock", "descriptors": "fantasy, '
#              'epic, progressive, complex, philosophical, surreal, poetic, '
#              'malevocals, melancholic, abstract", "avg_rating": 4.3, '
#              '"rating_count": 47415, "review_count": 833}]',
#   'name': 'top_rated_albums',
#   'role': 'function'},
#  {'content': 'Die fünf besten Alben basierend auf der durchschnittlichen '
#              'Bewertung sind:\n'
#              '\n'
#              '1. "The Black Saint and the Sinner Lady" von Mingus\n'
#              '2. "Wish You Were Here" von Pink Floyd\n'
#              '3. "To Pimp a Butterfly" von Kendrick Lamar\n'
#              '4. "A Love Supreme" von John Coltrane\n'
#              '5. "In the Court of the Crimson King" von King Crimson',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "テイラー・スウィフトがリリースしたすべてのアルバムを教えてください。"}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# テイラー・スウィフトがリリースしたすべてのアルバムは以下の通りです：
#
# 1. Folklore
#    - リリース日：2020-07-24
#    - ジャンル：Singer-Songwriter, Folk Pop
#
# 2. 1989
#    - リリース日：2014-10-27
#    - ジャンル：Synthpop, Electropop
#
# 3. Evermore
#    - リリース日：2020-12-11
#    - ジャンル：Singer-Songwriter, Folk Pop
#
# 4. Red
#    - リリース日：2012-10-22
#    - ジャンル：Pop, Singer-Songwriter, Pop Rock
#
# 5. Reputation
#    - リリース日：2017-11-10
#    - ジャンル：Electropop
#
# 6. Lover
#    - リリース日：2019-08-23
#    - ジャンル：Synthpop, Electropop
#
# 7. Speak Now
#    - リリース日：2010-10-25
#    - ジャンル：Pop Rock, Singer-Songwriter
#
# 8. Fearless
#    - リリース日：2008-11-11
#    - ジャンル：Country Pop, Pop Rock
#
# 9. Taylor Swift
#    - リリース日：2006-10-24
#    - ジャンル：Country Pop
#
# 10. Red (Taylor's Version)
#     - リリース日：2021-11-12
#     - ジャンル：Pop Rock, Singer-Songwriter
#
# 11. Fearless (Taylor's Version)
#     - リリース日：2021-04-09
#     - ジャンル：Country Pop, Pop Rock

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'テイラー・スウィフトがリリースしたすべてのアルバムを教えてください。', 'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n"artist_name": "Taylor Swift"\n}',
#                     'name': 'albums_by_artist'},
#   'role': 'assistant'},
#  {'content': '[{"release_name": "Folklore", "artist_name": "Taylor Swift", '
#              '"release_date": "2020-07-24", "primary_genres": '
#              '"Singer-Songwriter, Folk Pop", "secondary_genres": "Chamber Pop, '
#              'Indie Folk", "descriptors": "femalevocals, bittersweet, love, '
#              'soft, mellow, introspective, breakup, longing, calm, melodic", '
#              '"avg_rating": 3.35, "rating_count": 9228, "review_count": 157}, '
#              '{"release_name": "1989", "artist_name": "Taylor Swift", '
#              '"release_date": "2014-10-27", "primary_genres": "Synthpop, '
#              'Electropop", "secondary_genres": "Dance-Pop, Alt-Pop", '
#              '"descriptors": "romantic, breakup, femalevocals, melodic, love, '
#              'warm, playful, uplifting, sentimental, bittersweet", '
#              '"avg_rating": 3.18, "rating_count": 8278, "review_count": 105}, '
#              '{"release_name": "Evermore", "artist_name": "Taylor Swift", '
#              '"release_date": "2020-12-11", "primary_genres": '
#              '"Singer-Songwriter, Folk Pop", "secondary_genres": "Chamber Pop, '
#              'Indie Folk", "descriptors": "mellow, soft, femalevocals, '
#              'introspective, melancholic, love, winter, melodic, calm, '
#              'bittersweet", "avg_rating": 3.37, "rating_count": 5546, '
#              '"review_count": 58}, {"release_name": "Red", "artist_name": '
#              '"Taylor Swift", "release_date": "2012-10-22", "primary_genres": '
#              '"Pop, Singer-Songwriter, Pop Rock", "secondary_genres": "Country '
#              'Pop, Folk Pop, Pop Rock, Electropop, Heartland Rock", '
#              '"descriptors": "romantic, breakup, femalevocals, eclectic, '
#              'bittersweet, love, warm, autumn, melodic, melancholic", '
#              '"avg_rating": 3.21, "rating_count": 5530, "review_count": 82}, '
#              '{"release_name": "Reputation", "artist_name": "Taylor Swift", '
#              '"release_date": "2017-11-10", "primary_genres": "Electropop", '
#              '"secondary_genres": "Dance-Pop, Contemporary R&B, Trap[EDM], '
#              'Alt-Pop", "descriptors": "femalevocals, love, alcohol, playful, '
#              'rhythmic, energetic, melodic, hedonistic, bittersweet, breakup", '
#              '"avg_rating": 2.36, "rating_count": 5392, "review_count": 72}, '
#              '{"release_name": "Lover", "artist_name": "Taylor Swift", '
#              '"release_date": "2019-08-23", "primary_genres": "Synthpop, '
#              'Electropop", "secondary_genres": "Dance-Pop, Singer-Songwriter, '
#              'Alt-Pop", "descriptors": "love, femalevocals, romantic, '
#              'bittersweet, warm, optimistic, playful, melodic, longing, '
#              'uplifting", "avg_rating": 2.84, "rating_count": 5025, '
#              '"review_count": 73}, {"release_name": "Speak Now", '
#              '"artist_name": "Taylor Swift", "release_date": "2010-10-25", '
#              '"primary_genres": "Pop Rock, Singer-Songwriter", '
#              '"secondary_genres": "Country Pop, Soft Rock, Power Pop", '
#              '"descriptors": "femalevocals, romantic, breakup, love, '
#              'melancholic, melodic, longing, energetic, sentimental, '
#              'passionate", "avg_rating": 3.24, "rating_count": 3679, '
#              '"review_count": 41}, {"release_name": "Fearless", "artist_name": '
#              '"Taylor Swift", "release_date": "2008-11-11", "primary_genres": '
#              '"Country Pop, Pop Rock", "secondary_genres": "Teen Pop, '
#              'Singer-Songwriter, Power Pop", "descriptors": "femalevocals, '
#              'romantic, love, playful, uplifting, soft, passionate, '
#              'sentimental, summer, warm", "avg_rating": 2.95, "rating_count": '
#              '3628, "review_count": 59}, {"release_name": "Taylor Swift", '
#              '"artist_name": "Taylor Swift", "release_date": "2006-10-24", '
#              '"primary_genres": "Country Pop", "secondary_genres": '
#              '"Contemporary Country, Teen Pop, Pop Rock, Singer-Songwriter", '
#              '"descriptors": "femalevocals, love, melodic, happy, longing, '
#              'melancholic, passionate, romantic, sentimental, mellow", '
#              '"avg_rating": 2.56, "rating_count": 2726, "review_count": 31}, '
#              '{"release_name": "Red (Taylor\'s Version)", "artist_name": '
#              '"Taylor Swift", "release_date": "2021-11-12", "primary_genres": '
#              '"Pop Rock, Singer-Songwriter", "secondary_genres": "Country Pop, '
#              'Folk Pop, Heartland Rock", "descriptors": "femalevocals, '
#              'breakup, autumn, warm, longing, love, sentimental, melancholic, '
#              'romantic, melodic", "avg_rating": 3.54, "rating_count": 2626, '
#              '"review_count": 41}, {"release_name": "Fearless (Taylor\'s '
#              'Version)", "artist_name": "Taylor Swift", "release_date": '
#              '"2021-04-09", "primary_genres": "Country Pop, Pop Rock", '
#              '"secondary_genres": "Singer-Songwriter, Soft Rock, Teen Pop, '
#              'Power Pop", "descriptors": "femalevocals, love, sentimental, '
#              'romantic, melodic, breakup, uplifting, soft, playful, warm", '
#              '"avg_rating": 3.36, "rating_count": 2301, "review_count": 26}]',
#   'name': 'albums_by_artist',
#   'role': 'function'},
#  {'content': 'テイラー・スウィフトがリリースしたすべてのアルバムは以下の通りです：\n'
#              '\n'
#              '1. Folklore\n'
#              '   - リリース日：2020-07-24\n'
#              '   - ジャンル：Singer-Songwriter, Folk Pop\n'
#              '\n'
#              '2. 1989\n'
#              '   - リリース日：2014-10-27\n'
#              '   - ジャンル：Synthpop, Electropop\n'
#              '\n'
#              '3. Evermore\n'
#              '   - リリース日：2020-12-11\n'
#              '   - ジャンル：Singer-Songwriter, Folk Pop\n'
#              '\n'
#              '4. Red\n'
#              '   - リリース日：2012-10-22\n'
#              '   - ジャンル：Pop, Singer-Songwriter, Pop Rock\n'
#              '\n'
#              '5. Reputation\n'
#              '   - リリース日：2017-11-10\n'
#              '   - ジャンル：Electropop\n'
#              '\n'
#              '6. Lover\n'
#              '   - リリース日：2019-08-23\n'
#              '   - ジャンル：Synthpop, Electropop\n'
#              '\n'
#              '7. Speak Now\n'
#              '   - リリース日：2010-10-25\n'
#              '   - ジャンル：Pop Rock, Singer-Songwriter\n'
#              '\n'
#              '8. Fearless\n'
#              '   - リリース日：2008-11-11\n'
#              '   - ジャンル：Country Pop, Pop Rock\n'
#              '\n'
#              '9. Taylor Swift\n'
#              '   - リリース日：2006-10-24\n'
#              '   - ジャンル：Country Pop\n'
#              '\n'
#              "10. Red (Taylor's Version)\n"
#              '    - リリース日：2021-11-12\n'
#              '    - ジャンル：Pop Rock, Singer-Songwriter\n'
#              '\n'
#              "11. Fearless (Taylor's Version)\n"
#              '    - リリース日：2021-04-09\n'
#              '    - ジャンル：Country Pop, Pop Rock',
#   'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "'द वॉल' इति एल्बमस्य कलाकारः कः ?"}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# द वॉल एल्बमस्य कलाकारः पिंक फ्लोयद् हि।

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': "'द वॉल' इति एल्बमस्य कलाकारः कः ?", 'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n  "album_name": "द वॉल"\n}',
#                     'name': 'artist_by_album'},
#   'role': 'assistant'},
#  {'content': '{}', 'name': 'artist_by_album', 'role': 'function'},
#  {'content': 'द वॉल एल्बमस्य कलाकारः पिंक फ्लोयद् हि।', 'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "پرفيڪٽ“ گيت جو ڳائڻو ڪير آهي؟"}) #البم 'دی وال' کا فنکار کون ہے؟

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# "پرفيڪٽ" گيت جو ڳائڻو Ed Sheeran آهي.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': '”پرفيڪٽ“ گيت جو ڳائڻو ڪير آهي؟', 'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n"song_name": "پرفيڪٽ"\n}',
#                     'name': 'artist_by_song'},
#   'role': 'assistant'},
#  {'content': '{}', 'name': 'artist_by_song', 'role': 'function'},
#  {'content': '"پرفيڪٽ" گيت جو ڳائڻو Ed Sheeran آهي.', 'role': 'assistant'}]

# %%
available_functions = filter_functions(all_functions
, function_metadata)

conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "You are a helpful music assistant. answer the question briefly and use the information provided for function calling "}) \
            .add({"role": Role.USER.value, "content": "ما هي الأغاني التي صدرت في عام 2010؟"}) 

result = chat(conversation, model=Model.GPT3.value, functions=available_functions)
print(result)
# Out:
# بعض الأغاني التي صدرت في عام 2010 هي:
#
# 1. "Danza Kuduro" by Don Omar, Lucenzo
# 2. "Enchanted" by Taylor Swift
# 3. "Sure Thing" by Miguel
# 4. "Just The Way You Are" by Bruno Mars
# 5. "Es un Secreto" by Plan B
# 6. "Rolling in the Deep" by Adele
# 7. "Talking To The Moon" by Bruno Mars
#
# هذه فقط بعض الأمثلة وقد يكون هناك المزيد من الأغاني التي صدرت في عام 2010.

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'You are a helpful music assistant. answer the question briefly '
#              'and use the information provided for function calling ',
#   'role': 'system'},
#  {'content': 'ما هي الأغاني التي صدرت في عام 2010؟', 'role': 'user'},
#  {'content': None,
#   'function_call': {'arguments': '{\n"year": 2010\n}',
#                     'name': 'songs_by_release_year'},
#   'role': 'assistant'},
#  {'content': '[{"track_name": "Danza Kuduro", "artist(s)_name": "Don Omar, '
#              'Lucenzo", "artist_count": 2, "released_year": 2010, '
#              '"released_month": 1, "released_day": 1, "in_spotify_playlists": '
#              '17138, "in_spotify_charts": 37, "streams": "1279434863", '
#              '"in_apple_playlists": 119, "in_apple_charts": 81, '
#              '"in_deezer_playlists": "974", "in_deezer_charts": 1, '
#              '"in_shazam_charts": "503", "bpm": 130, "key": NaN, "mode": '
#              '"Major", "danceability_%": 47, "valence_%": 86, "energy_%": 92, '
#              '"acousticness_%": 8, "instrumentalness_%": 0, "liveness_%": 5, '
#              '"speechiness_%": 24}, {"track_name": "Enchanted", '
#              '"artist(s)_name": "Taylor Swift", "artist_count": 1, '
#              '"released_year": 2010, "released_month": 1, "released_day": 1, '
#              '"in_spotify_playlists": 4564, "in_spotify_charts": 16, '
#              '"streams": "621660989", "in_apple_playlists": 24, '
#              '"in_apple_charts": 101, "in_deezer_playlists": "113", '
#              '"in_deezer_charts": 0, "in_shazam_charts": "40", "bpm": 164, '
#              '"key": "G#", "mode": "Major", "danceability_%": 45, "valence_%": '
#              '24, "energy_%": 62, "acousticness_%": 8, "instrumentalness_%": '
#              '0, "liveness_%": 16, "speechiness_%": 3}, {"track_name": "Sure '
#              'Thing", "artist(s)_name": "Miguel", "artist_count": 1, '
#              '"released_year": 2010, "released_month": 5, "released_day": 25, '
#              '"in_spotify_playlists": 13801, "in_spotify_charts": 19, '
#              '"streams": "950906471", "in_apple_playlists": 137, '
#              '"in_apple_charts": 125, "in_deezer_playlists": "435", '
#              '"in_deezer_charts": 6, "in_shazam_charts": "285", "bpm": 81, '
#              '"key": "B", "mode": "Minor", "danceability_%": 68, "valence_%": '
#              '51, "energy_%": 60, "acousticness_%": 3, "instrumentalness_%": '
#              '0, "liveness_%": 19, "speechiness_%": 10}, {"track_name": "Just '
#              'The Way You Are", "artist(s)_name": "Bruno Mars", '
#              '"artist_count": 1, "released_year": 2010, "released_month": 1, '
#              '"released_day": 1, "in_spotify_playlists": 21106, '
#              '"in_spotify_charts": 13, "streams": "1641426668", '
#              '"in_apple_playlists": 82, "in_apple_charts": 0, '
#              '"in_deezer_playlists": "2,946", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 109, "key": "F", "mode": '
#              '"Major", "danceability_%": 63, "valence_%": 46, "energy_%": 85, '
#              '"acousticness_%": 1, "instrumentalness_%": 0, "liveness_%": 9, '
#              '"speechiness_%": 5}, {"track_name": "Es un Secreto", '
#              '"artist(s)_name": "Plan B", "artist_count": 1, "released_year": '
#              '2010, "released_month": 7, "released_day": 20, '
#              '"in_spotify_playlists": 492, "in_spotify_charts": 36, "streams": '
#              '"540654286", "in_apple_playlists": 4, "in_apple_charts": 3, '
#              '"in_deezer_playlists": "19", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 95, "key": "F#", "mode": '
#              '"Minor", "danceability_%": 84, "valence_%": 52, "energy_%": 77, '
#              '"acousticness_%": 12, "instrumentalness_%": 0, "liveness_%": 7, '
#              '"speechiness_%": 4}, {"track_name": "Rolling in the Deep", '
#              '"artist(s)_name": "Adele", "artist_count": 1, "released_year": '
#              '2010, "released_month": 11, "released_day": 29, '
#              '"in_spotify_playlists": 35684, "in_spotify_charts": 6, '
#              '"streams": "1472799873", "in_apple_playlists": 195, '
#              '"in_apple_charts": 125, "in_deezer_playlists": "6,280", '
#              '"in_deezer_charts": 2, "in_shazam_charts": "78", "bpm": 105, '
#              '"key": "G#", "mode": "Major", "danceability_%": 73, "valence_%": '
#              '52, "energy_%": 76, "acousticness_%": 13, "instrumentalness_%": '
#              '0, "liveness_%": 5, "speechiness_%": 3}, {"track_name": "Talking '
#              'To The Moon", "artist(s)_name": "Bruno Mars", "artist_count": 1, '
#              '"released_year": 2010, "released_month": 10, "released_day": 4, '
#              '"in_spotify_playlists": 7109, "in_spotify_charts": 2, "streams": '
#              '"1062956628", "in_apple_playlists": 5, "in_apple_charts": 0, '
#              '"in_deezer_playlists": "862", "in_deezer_charts": 0, '
#              '"in_shazam_charts": "0", "bpm": 146, "key": "C#", "mode": '
#              '"Minor", "danceability_%": 52, "valence_%": 7, "energy_%": 61, '
#              '"acousticness_%": 51, "instrumentalness_%": 0, "liveness_%": 11, '
#              '"speechiness_%": 3}]',
#   'name': 'songs_by_release_year',
#   'role': 'function'},
#  {'content': 'بعض الأغاني التي صدرت في عام 2010 هي:\n'
#              '\n'
#              '1. "Danza Kuduro" by Don Omar, Lucenzo\n'
#              '2. "Enchanted" by Taylor Swift\n'
#              '3. "Sure Thing" by Miguel\n'
#              '4. "Just The Way You Are" by Bruno Mars\n'
#              '5. "Es un Secreto" by Plan B\n'
#              '6. "Rolling in the Deep" by Adele\n'
#              '7. "Talking To The Moon" by Bruno Mars\n'
#              '\n'
#              'هذه فقط بعض الأمثلة وقد يكون هناك المزيد من الأغاني التي صدرت في '
#              'عام 2010.',
#   'role': 'assistant'}]

# %% [markdown]
# #### Use Web Server API

# %%
# change description of metadata
with open('functions.json', 'r') as file:
    function_metadata = json.load(file)

# %%
conversation = Conversation()
conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
            .add({"role": Role.USER.value, "content": "Can you please provide the top five albums based on average rating?"})

result = chat_web(conversation, model=Model.GPT3.value,
              function_metadata=function_metadata)
print(result)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# d:\Program Files\Programming\Function-Calling-LLMs\main.ipynb Cell 29 line 5
#       <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> conversation = Conversation()
#       <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> conversation.add({"role": Role.SYSTEM.value, "content": "Answer briefly."}) \
#       <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a>             .add({"role": Role.USER.value, "content": "How many top albums did Nirvana release?"})
# ----> <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=4'>5</a> result = chat_web(conversation, model=Model.GPT3.value,
#       <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=5'>6</a>               function_metadata=function_metadata)
#       <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=6'>7</a> print(result)
#
# d:\Program Files\Programming\Function-Calling-LLMs\main.ipynb Cell 29 line 1
#     <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=155'>156</a> while iteration < max_iterations:
#     <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=156'>157</a>     iteration += 1
# --> <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=157'>158</a>     response = conversation.send(model, function_metadata)
#     <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=158'>159</a>     conversation.add(response)
#     <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=160'>161</a>     if response.is_function_call:
#
# d:\Program Files\Programming\Function-Calling-LLMs\main.ipynb Cell 29 line 7
#      <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=71'>72</a> if len(functions) > 0:
#      <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=72'>73</a>     args.update({"function_call":"auto",
#      <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=73'>74</a>                  "functions":functions})
# ---> <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=75'>76</a> response = openai.ChatCompletion.create(**args)
#      <a href='vscode-notebook-cell:/d%3A/Program%20Files/Programming/Function-Calling-LLMs/main.ipynb#X40sZmlsZQ%3D%3D?line=76'>77</a> return Response.from_api(response)
#
# File d:\Program Files\Programming\Function-Calling-LLMs\.venv\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File d:\Program Files\Programming\Function-Calling-LLMs\.venv\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File d:\Program Files\Programming\Function-Calling-LLMs\.venv\Lib\site-packages\openai\api_requestor.py:299, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#    (...)
#     297         request_timeout=request_timeout,
#     298     )
# --> 299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File d:\Program Files\Programming\Function-Calling-LLMs\.venv\Lib\site-packages\openai\api_requestor.py:710, in APIRequestor._interpret_response(self, result, stream)
#     702     return (
#     703         self._interpret_response_line(
#     704             line, result.status_code, result.headers, stream=True
#     705         )
#     706         for line in parse_stream(result.iter_lines())
#     707     ), True
#     708 else:
#     709     return (
# --> 710         self._interpret_response_line(
#     711             result.content.decode("utf-8"),
#     712             result.status_code,
#     713             result.headers,
#     714             stream=False,
#     715         ),
#     716         False,
#     717     )
#
# File d:\Program Files\Programming\Function-Calling-LLMs\.venv\Lib\site-packages\openai\api_requestor.py:775, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     773 stream_error = stream and "error" in resp.data
#     774 if stream_error or not 200 <= rcode < 300:
# --> 775     raise self.handle_error_response(
#     776         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777     )
#     778 return resp
#
# APIError: Bad gateway. {"error":{"code":502,"message":"Bad gateway.","param":null,"type":"cf_bad_gateway"}} 502 {'error': {'code': 502, 'message': 'Bad gateway.', 'param': None, 'type': 'cf_bad_gateway'}} {'Date': 'Wed, 08 Nov 2023 14:10:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'X-Frame-Options': 'SAMEORIGIN', 'Referrer-Policy': 'same-origin', 'Cache-Control': 'private, max-age=0, no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Expires': 'Thu, 01 Jan 1970 00:00:01 GMT', 'Server': 'cloudflare', 'CF-RAY': '822e66beed601d84-FRA', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
pprint(conversation.messages_as_dicts)
# Out:
# [{'content': 'Answer briefly.', 'role': 'system'},
#  {'content': 'How many top albums did Nirvana release?', 'role': 'user'},
#  {'content': None,
#   'function_call': <OpenAIObject at 0x204e18e9df0> JSON: {
#   "name": "albums_by_artist",
#   "arguments": "{\n  \"artist_name\": \"Nirvana\"\n}"
# },
#   'role': 'assistant'},
#  {'content': '[{"release_name": "Nevermind", "artist_name": "Nirvana", '
#              '"release_date": "1991-09-24", "primary_genres": "Grunge, '
#              'Alternative Rock", "secondary_genres": "Punk Rock", '
#              '"descriptors": "energetic, rebellious, angry, malevocals, '
#              'apathetic, sarcastic, alienation, passionate, anxious, '
#              'self-hatred", "avg_rating": 3.93, "rating_count": 45503, '
#              '"review_count": 947}, {"release_name": "In utero", '
#              '"artist_name": "Nirvana", "release_date": "1993-09-21", '
#              '"primary_genres": "Grunge", "secondary_genres": "Noise Rock, '
#              'Post-Hardcore", "descriptors": "noisy, raw, sarcastic, '
#              'pessimistic, angry, rebellious, anxious, malevocals, dissonant, '
#              'introspective", "avg_rating": 3.98, "rating_count": 34762, '
#              '"review_count": 537}, {"release_name": "Bleach", "artist_name": '
#              '"Nirvana", "release_date": "1989-06-15", "primary_genres": '
#              '"Grunge", "secondary_genres": "Noise Rock, Sludge Metal, '
#              'Post-Hardcore", "descriptors": "raw, heavy, energetic, angry, '
#              'rebellious, malevocals, noisy, dark, misanthropic, aggressive", '
#              '"avg_rating": 3.5, "rating_count": 21183, "review_count": 373}]',
#   'name': 'albums_by_artist',
#   'role': 'function'},
#  {'content': 'Nirvana released a total of 3 top albums. The albums are:\n'
#              '\n'
#              '1. Nevermind\n'
#              '2. In utero\n'
#              '3. Bleach',
#   'role': 'assistant'}]
